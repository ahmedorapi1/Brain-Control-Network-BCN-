# %%
import os
import glob
import numpy as np
import math
import mne
from scipy.interpolate import griddata
from matplotlib import colormaps
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupShuffleSplit
from sklearn.model_selection import train_test_split

# %%
#   0 = Left fist   (R03,R07,R11 → T1)
#   1 = Right fist  (R03,R07,R11 → T2)
#   2 = Both fists  (R04,R08,R12 → T1)
#   3 = Both feet   (R04,R08,R12 → T2)
class EEGDatasetBuilder:
    def __init__(self, data_path, target_sfreq=160):
        self.data_path    = data_path
        self.target_sfreq = target_sfreq
        self.target_runs  = ['R03', 'R04', 'R07', 'R08', 'R11', 'R12']
        self._last_ch_names = None

        self.target_channels_clean = [
            "FC5","FC3","FC1","FCZ","FC2","FC4","FC6",
            "C5","C3","C1","CZ","C2","C4","C6",
            "CP5","CP3","CP1","CPZ","CP2","CP4","CP6",
            "F7","F5","F3","F1","FZ","F2","F4","F6","F8",
            "T7","T8",
            "P7","P5","P3","P1","PZ","P2","P4","P6","P8",
            "O1","OZ","O2"
        ]
    def load_subject(self):
        all_files = sorted(glob(
            os.path.join(self.data_path, "*", "*.edf")
        ))
        filtered = [
            f for f in all_files
            if any(run in os.path.basename(f) for run in self.target_runs)
        ]
        print(f"Total files: {len(all_files)}  |  After run filter: {len(filtered)}")
        return filtered
        
    def load_files(self):
        all_files = sorted(glob.glob(
            os.path.join(self.data_path, "*", "*.edf")
        ))
        filtered = [
            f for f in all_files
            if any(run in os.path.basename(f) for run in self.target_runs)
        ]
        print(f"Total files: {len(all_files)}  |  After run filter: {len(filtered)}")
        return filtered

    @staticmethod
    def _clean_ch_names(raw):
        rename_dict = {ch: ch.rstrip('.').upper() for ch in raw.ch_names}
        raw.rename_channels(rename_dict)
        return raw

    @staticmethod
    def _annotation_to_label(description, basename):
        is_fist_run = any(r in basename for r in ['R03', 'R07', 'R11'])
 
        if description == 'T0':
            return -1
        elif description == 'T1':
            return 0 if is_fist_run else 2   # left fist | both fists
        elif description == 'T2':
            return 1 if is_fist_run else 3   # right fist | both feet
        return -1
        
    def get_subjects(self):
        files = self.load_files()
        subjects = sorted(list({
            os.path.basename(f).split("R")[0]
            for f in files}))
        return subjects
    
    def build(self, tune=0):
        X, y     = [], []
        skipped  = 0
        last_raw = None
 
        all_subjects = self.get_subjects()
        tune_subject = set(all_subjects[:2])
        all_files    = self.load_files()
 
        if tune == 1:
            edf_files         = [f for f in all_files
                                  if os.path.basename(f).split("R")[0] in tune_subject]
            excluded_subjects = set()
        else:
            edf_files         = all_files
            excluded_subjects = tune_subject
 
        subjects = []
        for file in edf_files:
            subject_id = os.path.basename(file).split("R")[0]
            if subject_id in excluded_subjects:
                continue
            try:
                raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
                raw = self._clean_ch_names(raw)
 
                if raw.info['sfreq'] != self.target_sfreq:
                    raw.resample(self.target_sfreq, verbose=False)
 
                available = [ch for ch in self.target_channels_clean
                             if ch in raw.ch_names]
                if len(available) == 0:
                    skipped += 1
                    continue
                raw.pick(available, verbose=False)
 
                raw.filter(4., 35., verbose=False)
 
                events, event_id = mne.events_from_annotations(raw, verbose=False)
                if len(events) == 0:
                    skipped += 1
                    continue
 
                tmax   = 4.0
                epochs = mne.Epochs(
                    raw, events, event_id=event_id,
                    tmin=0.0, tmax=tmax,
                    baseline=None, preload=True,
                    reject_by_annotation=False,
                    verbose=False
                )
 
                data       = epochs.get_data()
                raw_labels = epochs.events[:, -1]
                descriptions = [
                    list(event_id.keys())[list(event_id.values()).index(l)]
                    for l in raw_labels
                ]
 
                basename = os.path.basename(file)
                labels   = np.array([
                    self._annotation_to_label(d, basename)
                    for d in descriptions
                ])
 
                valid  = labels >= 0
                data   = data[valid]
                labels = labels[valid]
 
                if len(data) == 0:
                    skipped += 1
                    continue
 
                expected_T = int(tmax * self.target_sfreq) + 1
                if data.shape[2] > expected_T:
                    data = data[:, :, :expected_T]
                elif data.shape[2] < expected_T:
                    pad  = expected_T - data.shape[2]
                    data = np.pad(data, ((0,0),(0,0),(0,pad)))
 
                X.append(data.astype(np.float32))
                y.append(labels)
                last_raw = raw
                subjects.append(np.array([subject_id] * len(labels)))
 
            except Exception as e:
                print(f"Skip: {os.path.basename(file)}  →  {e}")
                skipped += 1
                continue
 
        print(f"Skipped: {skipped} / {len(edf_files)}")
 
        if len(X) == 0:
            raise ValueError("No valid epochs found")
 
        X = np.concatenate(X, axis=0)
        y = np.concatenate(y, axis=0)
        self._last_ch_names = list(last_raw.ch_names)
 
        print(f"X shape  : {X.shape}  dtype: {X.dtype}")
        print(f"y shape  : {y.shape}  classes: {np.unique(y)}")
        print(f"Per class: {np.bincount(y)}")
        subjects = np.concatenate(subjects)
        return X, y, self._last_ch_names, subjects

# %%
def encode_labels(y):
    le    = LabelEncoder()
    y_enc = le.fit_transform(y).astype(np.int64)
    print(f"Classes: {le.classes_}  →  {np.unique(y_enc)}")
    return y_enc, le

# %%
# 3. ELECTRODE POSITIONS
def get_electrode_positions(ch_names):
    montage   = mne.channels.make_standard_montage("standard_1020")
    pos       = montage.get_positions()['ch_pos']
    pos_upper = {k.upper(): v for k, v in pos.items()}

    matched_ch     = []
    matched_coords = []
    for ch in ch_names:
        if ch.upper() in pos_upper:
            matched_ch.append(ch)
            matched_coords.append(pos_upper[ch.upper()])

    if len(matched_ch) == 0:
        raise ValueError("No channels matched montage positions")

    coords = np.array(matched_coords)
    x_sel  = coords[:, 0]
    y_sel  = coords[:, 1]

    x_norm = (x_sel - x_sel.min()) / (x_sel.max() - x_sel.min()) * 2 - 1
    y_norm = (y_sel - y_sel.min()) / (y_sel.max() - y_sel.min()) * 2 - 1

    xi, yi = np.meshgrid(np.linspace(-1, 1, 32), np.linspace(-1, 1, 32))

    print(f"Electrode positions: {len(matched_ch)} / {len(ch_names)} matched")
    return x_norm, y_norm, xi, yi, matched_ch

# %%
class EEGTorchDataset(Dataset):
    """
    X: (N, C, T)  float32
    y: (N,)       int64
    Output: (C, T) tensor مباشرة للموديل
    """
    def __init__(self, X, y):
        # Normalize كل sample على حدة
        mean = X.mean(axis=(1, 2), keepdims=True)
        std  = X.std(axis=(1, 2),  keepdims=True) + 1e-8
        self.X = ((X - mean) / std).astype(np.float32)
        self.y = y.astype(np.int64)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.X[idx]),   # (C, T)
            torch.tensor(self.y[idx])
        )

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    if torch.backends.mps.is_available():
        return torch.device("mps")
    return torch.device("cpu")

# %%
def make_weighted_sampler(y_train):
    """
    WeightedRandomSampler عشان نعالج الـ class imbalance
    """
    class_counts  = np.bincount(y_train)
    sample_weights = np.array([1.0 / class_counts[y] for y in y_train])
    sampler = WeightedRandomSampler(
        weights     = torch.tensor(sample_weights, dtype=torch.float32),
        num_samples = len(sample_weights),
        replacement = True
    )
    print(f"Class counts: {class_counts}")
    return sampler

# %%
def train(model, loader, val_loader, device, optimizer_ft=None, scheduler_ft=None, epochs=50, class_counts=None,
          patience=5, save_path='/kaggle/working/eeg_model_best.pth'):
 
    model.to(device)
 
    if class_counts is not None:
        weights = 1.0 / torch.tensor(class_counts, dtype=torch.float32)
        weights = (weights / weights.sum()).to(device)
        loss_fn = nn.CrossEntropyLoss(weight=weights)
        print(f"Using weighted loss: {weights.cpu().numpy()}")
    else:
         loss_fn = nn.CrossEntropyLoss()
                
    if optimizer_ft is not None:
        optimizer = optimizer_ft
    else:
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=1e-4,         
            weight_decay=1e-4  
        )
    
    if scheduler_ft is not None:
        scheduler = scheduler_ft
    else:
        scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer, step_size=15, gamma=0.5  
        )
 
    max_grad_norm = 1.0
 
    best_val_loss     = float('inf')
    epochs_no_improve = 0
 
    for epoch in range(epochs):
        # ── Training ─────────────────────────────────────────
        model.train()
        total_loss, correct, total = 0.0, 0, 0
 
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
 
            optimizer.zero_grad()
            out  = model(X_batch)
            loss = loss_fn(out, y_batch)
            loss.backward()
            # torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm) 
            optimizer.step()
            total_loss += loss.item()
            correct    += (out.argmax(1) == y_batch).sum().item()
            total      += len(y_batch)
 
        # ── Validation ───────────────────────────────────────
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                out      = model(X_batch)
                val_loss += loss_fn(out, y_batch).item()
                val_correct += (out.argmax(1) == y_batch).sum().item()
                val_total   += len(y_batch)
        scheduler.step()
         
 
        current_lr = optimizer.param_groups[0]['lr']   
    
        print(f"Epoch {epoch+1:02d}/{epochs}  "
              f"train_loss={total_loss:.2f}  "
              f"val_loss={val_loss:.2f}  "
              f"train_acc={correct/total*100:.1f}%  "
              f"val_acc={val_correct/val_total*100:.1f}%  "  
              f"lr={current_lr:.2e}")
 
        if val_loss < best_val_loss:
            best_val_loss     = val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
            print(f"  val_loss improved → best model saved")
        else:
            epochs_no_improve += 1
            print(f"  no improvement ({epochs_no_improve}/{patience})")
            if epochs_no_improve >= patience:
                print(f"\n Early stopping at epoch {epoch+1} "
                      f"— best val_loss={best_val_loss:.4f}")
                break
    if os.path.exists(save_path):
        model.load_state_dict(torch.load(save_path, weights_only=False))
        print(f"\n Best model restored from {save_path}")
    else:
        print(f"\n No saved model found — keeping current weights")

# %%
def evaluate(model, loader, device, label_names=None):
    model.eval()
    all_preds, all_true = [], []
    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            out     = model(X_batch)
            preds   = torch.argmax(out, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_true.extend(y_batch.numpy())

    all_preds = np.array(all_preds)
    all_true  = np.array(all_true)
    acc       = (all_preds == all_true).mean() * 100
    print(f"\nVal Accuracy: {acc:.2f}%\n")

    if label_names is None:
        num_cls    = len(np.unique(all_true))
        label_names = [f"Class {i}" for i in range(num_cls)]

    report = classification_report(all_true, all_preds, target_names=label_names)

    with open('/kaggle/working/report.txt', 'w') as f:
        f.write(report)
    
    print(report)
    return all_preds, all_true

# %%
def plot_confusion_matrix(model, loader, device, label_names=None):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            out     = model(X_batch)
            preds   = out.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y_batch.numpy())

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=label_names or list(range(cm.shape[0]))
    )

    fig, ax = plt.subplots(figsize=(6, 5))
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title("Confusion Matrix")
    plt.tight_layout()
    plt.show()

# %%
def save_model(model, num_classes, label_encoder, ch_names, matched_ch,
               path='/kaggle/working/eeg_model.pth'):
    torch.save({
        'model_state_dict': model.state_dict(),
        'num_classes':      num_classes,
        'label_classes':    label_encoder.classes_,
        'ch_names':         ch_names,
        'matched_ch':       matched_ch,
    }, path)
    print(f"Model saved → {path}")

# %%
def load_model(path='/kaggle/working/eeg_model.pth'):
    checkpoint = torch.load(path, map_location='cpu', weights_only=False)
    model      = CNN_LSTM(num_classes=checkpoint['num_classes'])  
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    print(f"Model loaded  classes={checkpoint['label_classes']}")
    return model, checkpoint

# %%
class EEG_ATCNet(nn.Module):
    def __init__(self, n_channels=44, num_classes=4):
        super().__init__()

        # Spatial Block
        self.spatial = nn.Sequential(
            nn.Conv2d(1, 32, (n_channels, 1), bias=False),
            nn.BatchNorm2d(32),
            nn.ELU(),
            nn.Dropout(0.5)
        )

        # Temporal Block
        self.temporal = nn.Sequential(
            nn.Conv1d(32, 64, kernel_size=25, padding=12),
            nn.BatchNorm1d(64),
            nn.ELU(),

            nn.Conv1d(64, 64, kernel_size=15, padding=7),
            nn.BatchNorm1d(64),
            nn.ELU(),

            nn.AvgPool1d(4),
            nn.Dropout(0.5),

            nn.Conv1d(64, 128, kernel_size=7, padding=3),
            nn.BatchNorm1d(128),
            nn.ELU(),

            nn.AvgPool1d(4),
            nn.Dropout(0.5)
        )

        # Multi-head Attention
        self.attention = nn.MultiheadAttention(
            embed_dim=128,
            num_heads=8,
            batch_first=True,
            dropout=0.25
        )

        self.norm = nn.LayerNorm(128)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(128, 256),
            nn.ELU(),
            nn.Dropout(0.5),

            nn.Linear(256, 128),
            nn.ELU(),
            nn.Dropout(0.5),

            nn.Linear(128, num_classes)
        )

    def forward(self, x):

        # x = (B,C,T)

        x = x.unsqueeze(1)

        x = self.spatial(x)

        x = x.squeeze(2)

        x = self.temporal(x)

        x = x.permute(0, 2, 1)

        attn_out, _ = self.attention(x, x, x)

        x = self.norm(x + attn_out)

        # Global Average Pooling
        x = x.mean(dim=1)

        return self.classifier(x)

# %%
class ATCNet_LSTM(nn.Module):
    def __init__(self, n_channels=44, n_times=641, 
                 num_classes=4, hidden=256):
        super().__init__()
        
        self.spatial = nn.Sequential(
            nn.Conv2d(1, 16, (n_channels, 1)),  
            nn.BatchNorm2d(16),
            nn.ELU(),
            nn.Dropout(0.25)
        )
        
        self.temporal = nn.Sequential(
            nn.Conv1d(16, 32, kernel_size=25, padding=12),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.AvgPool1d(8),
            nn.Dropout(0.25),
            nn.Conv1d(32, 64, kernel_size=15, padding=7),
            nn.BatchNorm1d(64),
            nn.ELU(),
            nn.AvgPool1d(4),
            nn.Dropout(0.25)
        )
        
        self.attention = nn.MultiheadAttention(
            embed_dim=64,
            num_heads=8,
            dropout=0.25,
            batch_first=True
        )
        self.attn_norm = nn.LayerNorm(64)
        
        self.lstm = nn.LSTM(
            input_size=64,
            hidden_size=hidden,
            num_layers=2,
            batch_first=True,
            dropout=0.3,
            bidirectional=True
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(hidden * 2, 256),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # x: (B, C, T)
        B = x.size(0)
        
        
        x = x.unsqueeze(1)              # (B, 1, C, T)
        x = self.spatial(x)             # (B, 16, 1, T)
        x = x.squeeze(2)                # (B, 16, T)
        
        x = self.temporal(x)            # (B, 64, T')
        
        x = x.permute(0, 2, 1)         # (B, T', 64)
        attn_out, _ = self.attention(x, x, x)
        x = self.attn_norm(x + attn_out)
        
        # LSTM
        out, _ = self.lstm(x)           
        out = out[:, -1, :]             
        
        return self.classifier(out)

# %%
class CNN_LSTM(nn.Module):
    def __init__(self, n_channels=44, n_times=641, num_classes=4, hidden=256):
        super().__init__()

        self.cnn = nn.Sequential(
            nn.Conv1d(n_channels, 64,  kernel_size=25, stride=2, padding=12),
            nn.BatchNorm1d(64),
            nn.ELU(),
            nn.Dropout(0.25),

            nn.Conv1d(64, 128, kernel_size=15, stride=2, padding=7),
            nn.BatchNorm1d(128),
            nn.ELU(),
            nn.Dropout(0.25),

            nn.Conv1d(128, 256, kernel_size=5, stride=2, padding=2),
            nn.BatchNorm1d(256),
            nn.ELU(),
            nn.Dropout(0.25),
        )

        self.lstm = nn.LSTM(
            input_size=256,
            hidden_size=hidden,
            num_layers=2,
            batch_first=True,
            dropout=0.3,
            bidirectional=True
        )

        self.classifier = nn.Sequential(
            nn.Linear(hidden * 2, 128),  # *2 لأن bidirectional
            nn.ELU(),
            nn.Dropout(0.4),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # x: (B, C, T)
        feat = self.cnn(x)           # (B, 256, T')
        feat = feat.permute(0, 2, 1) # (B, T', 256)
        out, _ = self.lstm(feat)     # (B, T', hidden*2)
        out = out[:, -1, :]          # آخر timestep
        return self.classifier(out)

# %%
DATA_PATH = "/kaggle/input/datasets/brianleung2020/eeg-motor-movementimagery-dataset/files"

for f in ["/kaggle/working/cache_train.npy", "/kaggle/working/cache_val.npy"]:
    if os.path.exists(f):
        os.remove(f)
        print(f"Deleted old cache: {f}")

builder = EEGDatasetBuilder(DATA_PATH)


X, y_raw, ch_names, subjects  = builder.build()
y, label_encoder = encode_labels(y_raw)
num_classes = len(label_encoder.classes_)   # 4

x_sel, y_sel, xi, yi, matched_ch = get_electrode_positions(ch_names)

ch_idx = [ch_names.index(ch) for ch in matched_ch]
X = X[:, ch_idx, :]

print(f"\nFinal X : {X.shape}")
print(f"Classes : {num_classes}  per class: {np.bincount(y)}")

gss = GroupShuffleSplit(test_size=0.20, random_state=42)

train_idx, val_idx = next(gss.split(X, y, groups=subjects))

X_train, X_val = X[train_idx], X[val_idx]
y_train, y_val = y[train_idx], y[val_idx]

train_ds = EEGTorchDataset(X_train, y_train)
val_ds   = EEGTorchDataset(X_val,   y_val)

pin     = torch.cuda.is_available()
sampler = make_weighted_sampler(y_train)

train_loader = DataLoader(
    train_ds,
    batch_size=32,
    shuffle=True,
    num_workers=2,
    pin_memory=pin
)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                          num_workers=2, pin_memory=pin)
# Out:
# Total files: 1526  |  After run filter: 654
# Total files: 1526  |  After run filter: 654
# /tmp/ipykernel_58/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_58/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_58/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_58/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_58/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_58/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# Skipped: 0 / 654
# X shape  : (9795, 44, 641)  dtype: float32
# y shape  : (9795,)  classes: [0 1 2 3]
# Per class: [2452 2445 2470 2428]
# Classes: [0 1 2 3]  →  [0 1 2 3]
# Electrode positions: 44 / 44 matched
#
# Final X : (9795, 44, 641)
# Classes : 4  per class: [2452 2445 2470 2428]
# Class counts: [1956 1957 1973 1940]

# %%
# model = EEG_ATCNet(n_channels=44, num_classes=4)

model = ATCNet_LSTM(n_channels=44, n_times=641, num_classes=4)



device       = get_device()
# model        = CNN_LSTM()
class_counts = np.bincount(y_train)

print(f"\nDevice : {device}")
print(f"Input shape : {train_ds[0][0].shape}")  # (44, 641)
# Out:
# Device : cuda
# Input shape : torch.Size([44, 641])

# %%
train(model, train_loader, val_loader, device, epochs=200, class_counts=class_counts,
      patience=90, save_path='/kaggle/working/eeg_model_best.pth')

save_model(model, num_classes, label_encoder, ch_names, matched_ch)
# Out:
# Using weighted loss: [0.25005502 0.24992724 0.24790047 0.25211734]
# Epoch 01/200  train_loss=337.98  val_loss=85.69  train_acc=27.0%  val_acc=28.8%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 02/200  train_loss=334.55  val_loss=84.79  train_acc=28.9%  val_acc=29.7%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 03/200  train_loss=331.49  val_loss=84.97  train_acc=31.4%  val_acc=30.4%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 04/200  train_loss=329.19  val_loss=85.75  train_acc=31.7%  val_acc=29.4%  lr=1.00e-04
#   no improvement (2/90)
# Epoch 05/200  train_loss=326.65  val_loss=86.02  train_acc=34.0%  val_acc=33.8%  lr=1.00e-04
#   no improvement (3/90)
# Epoch 06/200  train_loss=324.23  val_loss=83.08  train_acc=34.9%  val_acc=36.6%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 07/200  train_loss=320.73  val_loss=84.14  train_acc=37.1%  val_acc=33.9%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 08/200  train_loss=317.10  val_loss=82.69  train_acc=37.9%  val_acc=34.1%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 09/200  train_loss=315.03  val_loss=82.95  train_acc=39.0%  val_acc=34.2%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 10/200  train_loss=311.95  val_loss=83.03  train_acc=40.2%  val_acc=36.6%  lr=1.00e-04
#   no improvement (2/90)
# Epoch 11/200  train_loss=309.88  val_loss=81.78  train_acc=41.4%  val_acc=38.2%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 12/200  train_loss=305.03  val_loss=81.45  train_acc=42.3%  val_acc=37.7%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 13/200  train_loss=304.37  val_loss=79.07  train_acc=42.1%  val_acc=40.0%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 14/200  train_loss=300.69  val_loss=80.85  train_acc=42.9%  val_acc=39.0%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 15/200  train_loss=297.38  val_loss=82.06  train_acc=43.6%  val_acc=39.3%  lr=5.00e-05
#   no improvement (2/90)
# Epoch 16/200  train_loss=294.64  val_loss=80.70  train_acc=44.8%  val_acc=38.9%  lr=5.00e-05
#   no improvement (3/90)
# Epoch 17/200  train_loss=291.82  val_loss=80.93  train_acc=45.9%  val_acc=39.9%  lr=5.00e-05
#   no improvement (4/90)
# Epoch 18/200  train_loss=289.78  val_loss=80.02  train_acc=45.7%  val_acc=40.7%  lr=5.00e-05
#   no improvement (5/90)
# Epoch 19/200  train_loss=286.09  val_loss=80.57  train_acc=46.3%  val_acc=39.8%  lr=5.00e-05
#   no improvement (6/90)
# Epoch 20/200  train_loss=286.92  val_loss=80.66  train_acc=46.6%  val_acc=40.2%  lr=5.00e-05
#   no improvement (7/90)
# Epoch 21/200  train_loss=285.78  val_loss=79.68  train_acc=47.2%  val_acc=41.7%  lr=5.00e-05
#   no improvement (8/90)
# Epoch 22/200  train_loss=283.45  val_loss=80.33  train_acc=47.3%  val_acc=41.3%  lr=5.00e-05
#   no improvement (9/90)
# Epoch 23/200  train_loss=281.65  val_loss=79.11  train_acc=47.5%  val_acc=41.8%  lr=5.00e-05
#   no improvement (10/90)
# Epoch 24/200  train_loss=281.04  val_loss=79.09  train_acc=47.5%  val_acc=42.9%  lr=5.00e-05
#   no improvement (11/90)
# Epoch 25/200  train_loss=277.50  val_loss=77.47  train_acc=48.2%  val_acc=43.4%  lr=5.00e-05
#   val_loss improved → best model saved
# Epoch 26/200  train_loss=278.73  val_loss=77.03  train_acc=48.3%  val_acc=43.1%  lr=5.00e-05
#   val_loss improved → best model saved
# Epoch 27/200  train_loss=276.63  val_loss=78.46  train_acc=48.9%  val_acc=41.6%  lr=5.00e-05
#   no improvement (1/90)
# Epoch 28/200  train_loss=273.14  val_loss=78.63  train_acc=50.1%  val_acc=42.8%  lr=5.00e-05
#   no improvement (2/90)
# Epoch 29/200  train_loss=272.10  val_loss=76.47  train_acc=49.9%  val_acc=43.5%  lr=5.00e-05
#   val_loss improved → best model saved
# Epoch 30/200  train_loss=270.87  val_loss=78.00  train_acc=49.6%  val_acc=43.0%  lr=2.50e-05
#   no improvement (1/90)
# Epoch 31/200  train_loss=269.90  val_loss=76.63  train_acc=50.7%  val_acc=43.9%  lr=2.50e-05
#   no improvement (2/90)
# Epoch 32/200  train_loss=265.71  val_loss=78.06  train_acc=51.0%  val_acc=43.5%  lr=2.50e-05
#   no improvement (3/90)
# Epoch 33/200  train_loss=267.77  val_loss=77.11  train_acc=50.7%  val_acc=45.4%  lr=2.50e-05
#   no improvement (4/90)
# Epoch 34/200  train_loss=265.58  val_loss=76.64  train_acc=51.1%  val_acc=44.6%  lr=2.50e-05
#   no improvement (5/90)
# Epoch 35/200  train_loss=264.01  val_loss=75.01  train_acc=52.0%  val_acc=45.4%  lr=2.50e-05
#   val_loss improved → best model saved
# Epoch 36/200  train_loss=265.95  val_loss=77.00  train_acc=50.6%  val_acc=44.0%  lr=2.50e-05
#   no improvement (1/90)
# Epoch 37/200  train_loss=262.76  val_loss=76.35  train_acc=52.0%  val_acc=45.2%  lr=2.50e-05
#   no improvement (2/90)
# Epoch 38/200  train_loss=262.75  val_loss=76.68  train_acc=51.6%  val_acc=45.0%  lr=2.50e-05
#   no improvement (3/90)
# Epoch 39/200  train_loss=261.99  val_loss=76.38  train_acc=52.1%  val_acc=45.1%  lr=2.50e-05
#   no improvement (4/90)
# Epoch 40/200  train_loss=260.96  val_loss=75.98  train_acc=51.8%  val_acc=45.1%  lr=2.50e-05
#   no improvement (5/90)
# Epoch 41/200  train_loss=263.07  val_loss=75.63  train_acc=52.0%  val_acc=46.5%  lr=2.50e-05
#   no improvement (6/90)
# Epoch 42/200  train_loss=260.65  val_loss=75.64  train_acc=52.2%  val_acc=46.7%  lr=2.50e-05
#   no improvement (7/90)
# Epoch 43/200  train_loss=259.59  val_loss=74.04  train_acc=52.8%  val_acc=46.8%  lr=2.50e-05
#   val_loss improved → best model saved
# Epoch 44/200  train_loss=261.04  val_loss=74.44  train_acc=51.8%  val_acc=46.4%  lr=2.50e-05
#   no improvement (1/90)
# Epoch 45/200  train_loss=259.20  val_loss=74.76  train_acc=52.4%  val_acc=45.6%  lr=1.25e-05
#   no improvement (2/90)
# Epoch 46/200  train_loss=256.03  val_loss=74.49  train_acc=53.1%  val_acc=46.4%  lr=1.25e-05
#   no improvement (3/90)
# Epoch 47/200  train_loss=255.19  val_loss=76.50  train_acc=53.4%  val_acc=45.9%  lr=1.25e-05
#   no improvement (4/90)
# Epoch 48/200  train_loss=257.27  val_loss=75.35  train_acc=53.1%  val_acc=46.9%  lr=1.25e-05
#   no improvement (5/90)
# Epoch 49/200  train_loss=255.80  val_loss=75.82  train_acc=53.9%  val_acc=45.8%  lr=1.25e-05
#   no improvement (6/90)
# Epoch 50/200  train_loss=252.29  val_loss=76.25  train_acc=54.2%  val_acc=46.7%  lr=1.25e-05
#   no improvement (7/90)
# Epoch 51/200  train_loss=253.41  val_loss=75.28  train_acc=54.0%  val_acc=46.9%  lr=1.25e-05
#   no improvement (8/90)
# Epoch 52/200  train_loss=253.55  val_loss=75.46  train_acc=53.4%  val_acc=46.8%  lr=1.25e-05
#   no improvement (9/90)
# Epoch 53/200  train_loss=252.45  val_loss=75.72  train_acc=53.3%  val_acc=46.5%  lr=1.25e-05
#   no improvement (10/90)
# Epoch 54/200  train_loss=252.03  val_loss=74.68  train_acc=53.4%  val_acc=46.7%  lr=1.25e-05
#   no improvement (11/90)
# Epoch 55/200  train_loss=252.55  val_loss=74.91  train_acc=54.2%  val_acc=46.7%  lr=1.25e-05
#   no improvement (12/90)
# Epoch 56/200  train_loss=251.32  val_loss=76.08  train_acc=54.1%  val_acc=46.2%  lr=1.25e-05
#   no improvement (13/90)
# Epoch 57/200  train_loss=253.60  val_loss=75.48  train_acc=53.7%  val_acc=46.9%  lr=1.25e-05
#   no improvement (14/90)
# Epoch 58/200  train_loss=250.06  val_loss=74.70  train_acc=54.9%  val_acc=47.0%  lr=1.25e-05
#   no improvement (15/90)
# Epoch 59/200  train_loss=251.32  val_loss=74.67  train_acc=54.4%  val_acc=46.8%  lr=1.25e-05
#   no improvement (16/90)
# Epoch 60/200  train_loss=252.08  val_loss=73.94  train_acc=54.5%  val_acc=47.9%  lr=6.25e-06
#   val_loss improved → best model saved
# Epoch 61/200  train_loss=249.94  val_loss=74.21  train_acc=54.8%  val_acc=47.4%  lr=6.25e-06
#   no improvement (1/90)
# Epoch 62/200  train_loss=249.65  val_loss=74.91  train_acc=54.8%  val_acc=47.7%  lr=6.25e-06
#   no improvement (2/90)
# Epoch 63/200  train_loss=250.47  val_loss=74.57  train_acc=54.1%  val_acc=47.5%  lr=6.25e-06
#   no improvement (3/90)
# Epoch 64/200  train_loss=248.31  val_loss=74.80  train_acc=55.9%  val_acc=47.2%  lr=6.25e-06
#   no improvement (4/90)
# Epoch 65/200  train_loss=250.91  val_loss=74.40  train_acc=54.6%  val_acc=48.0%  lr=6.25e-06
#   no improvement (5/90)
# Epoch 66/200  train_loss=250.13  val_loss=75.08  train_acc=54.4%  val_acc=47.2%  lr=6.25e-06
#   no improvement (6/90)
# Epoch 67/200  train_loss=248.29  val_loss=75.40  train_acc=55.3%  val_acc=47.4%  lr=6.25e-06
#   no improvement (7/90)
# Epoch 68/200  train_loss=250.33  val_loss=75.39  train_acc=54.6%  val_acc=47.4%  lr=6.25e-06
#   no improvement (8/90)
# Epoch 69/200  train_loss=250.55  val_loss=75.07  train_acc=54.2%  val_acc=47.5%  lr=6.25e-06
#   no improvement (9/90)
# Epoch 70/200  train_loss=249.10  val_loss=74.53  train_acc=54.2%  val_acc=47.9%  lr=6.25e-06
#   no improvement (10/90)
# Epoch 71/200  train_loss=248.26  val_loss=75.42  train_acc=55.2%  val_acc=47.8%  lr=6.25e-06
#   no improvement (11/90)
# Epoch 72/200  train_loss=247.74  val_loss=75.00  train_acc=55.2%  val_acc=47.9%  lr=6.25e-06
#   no improvement (12/90)
# Epoch 73/200  train_loss=248.50  val_loss=74.61  train_acc=55.1%  val_acc=48.1%  lr=6.25e-06
#   no improvement (13/90)
# Epoch 74/200  train_loss=247.72  val_loss=74.80  train_acc=54.9%  val_acc=47.7%  lr=6.25e-06
#   no improvement (14/90)
# Epoch 75/200  train_loss=248.89  val_loss=75.57  train_acc=54.4%  val_acc=47.4%  lr=3.13e-06
#   no improvement (15/90)
# Epoch 76/200  train_loss=249.97  val_loss=74.34  train_acc=54.1%  val_acc=47.8%  lr=3.13e-06
#   no improvement (16/90)
# Epoch 77/200  train_loss=248.12  val_loss=74.11  train_acc=54.6%  val_acc=48.2%  lr=3.13e-06
#   no improvement (17/90)
# Epoch 78/200  train_loss=247.65  val_loss=74.66  train_acc=54.8%  val_acc=47.7%  lr=3.13e-06
#   no improvement (18/90)
# Epoch 79/200  train_loss=245.89  val_loss=74.45  train_acc=55.4%  val_acc=47.9%  lr=3.13e-06
#   no improvement (19/90)
# Epoch 80/200  train_loss=247.40  val_loss=74.57  train_acc=55.2%  val_acc=47.7%  lr=3.13e-06
#   no improvement (20/90)
# Epoch 81/200  train_loss=249.22  val_loss=74.60  train_acc=54.7%  val_acc=47.9%  lr=3.13e-06
#   no improvement (21/90)
# Epoch 82/200  train_loss=249.34  val_loss=74.43  train_acc=54.3%  val_acc=47.8%  lr=3.13e-06
#   no improvement (22/90)
# Epoch 83/200  train_loss=248.72  val_loss=74.36  train_acc=54.4%  val_acc=47.9%  lr=3.13e-06
#   no improvement (23/90)
# Epoch 84/200  train_loss=247.26  val_loss=74.26  train_acc=54.9%  val_acc=47.9%  lr=3.13e-06
#   no improvement (24/90)
# Epoch 85/200  train_loss=246.52  val_loss=74.28  train_acc=55.0%  val_acc=47.8%  lr=3.13e-06
#   no improvement (25/90)
# Epoch 86/200  train_loss=249.08  val_loss=73.77  train_acc=54.7%  val_acc=48.2%  lr=3.13e-06
#   val_loss improved → best model saved
# Epoch 87/200  train_loss=248.35  val_loss=74.10  train_acc=55.2%  val_acc=48.3%  lr=3.13e-06
#   no improvement (1/90)
# Epoch 88/200  train_loss=246.03  val_loss=74.44  train_acc=55.2%  val_acc=48.1%  lr=3.13e-06
#   no improvement (2/90)
# Epoch 89/200  train_loss=247.33  val_loss=73.33  train_acc=55.0%  val_acc=48.2%  lr=3.13e-06
#   val_loss improved → best model saved
# Epoch 90/200  train_loss=244.33  val_loss=74.97  train_acc=55.7%  val_acc=47.9%  lr=1.56e-06
#   no improvement (1/90)
# Epoch 91/200  train_loss=247.65  val_loss=74.30  train_acc=54.9%  val_acc=47.7%  lr=1.56e-06
#   no improvement (2/90)
# Epoch 92/200  train_loss=246.70  val_loss=74.81  train_acc=55.3%  val_acc=47.5%  lr=1.56e-06
#   no improvement (3/90)
# Epoch 93/200  train_loss=245.29  val_loss=73.74  train_acc=55.2%  val_acc=48.3%  lr=1.56e-06
#   no improvement (4/90)
# Epoch 94/200  train_loss=249.66  val_loss=73.55  train_acc=55.0%  val_acc=48.1%  lr=1.56e-06
#   no improvement (5/90)
# Epoch 95/200  train_loss=245.42  val_loss=73.56  train_acc=55.7%  val_acc=47.9%  lr=1.56e-06
#   no improvement (6/90)
# Epoch 96/200  train_loss=247.46  val_loss=74.72  train_acc=55.1%  val_acc=47.8%  lr=1.56e-06
#   no improvement (7/90)
# Epoch 97/200  train_loss=245.02  val_loss=74.57  train_acc=55.5%  val_acc=47.8%  lr=1.56e-06
#   no improvement (8/90)
# Epoch 98/200  train_loss=246.59  val_loss=75.11  train_acc=55.2%  val_acc=48.0%  lr=1.56e-06
#   no improvement (9/90)
# Epoch 99/200  train_loss=246.78  val_loss=74.56  train_acc=54.8%  val_acc=47.7%  lr=1.56e-06
#   no improvement (10/90)
# Epoch 100/200  train_loss=246.85  val_loss=74.36  train_acc=55.0%  val_acc=47.9%  lr=1.56e-06
#   no improvement (11/90)
# Epoch 101/200  train_loss=245.60  val_loss=73.82  train_acc=55.0%  val_acc=48.0%  lr=1.56e-06
#   no improvement (12/90)
# Epoch 102/200  train_loss=245.73  val_loss=74.21  train_acc=55.5%  val_acc=48.0%  lr=1.56e-06
#   no improvement (13/90)
# Epoch 103/200  train_loss=246.41  val_loss=74.58  train_acc=55.7%  val_acc=48.1%  lr=1.56e-06
#   no improvement (14/90)
# Epoch 104/200  train_loss=246.30  val_loss=73.30  train_acc=55.3%  val_acc=48.5%  lr=1.56e-06
#   val_loss improved → best model saved
# Epoch 105/200  train_loss=247.37  val_loss=73.94  train_acc=55.1%  val_acc=47.8%  lr=7.81e-07
#   no improvement (1/90)
# Epoch 106/200  train_loss=246.04  val_loss=74.51  train_acc=55.0%  val_acc=47.9%  lr=7.81e-07
#   no improvement (2/90)
# Epoch 107/200  train_loss=247.38  val_loss=74.11  train_acc=54.9%  val_acc=48.0%  lr=7.81e-07
#   no improvement (3/90)
# Epoch 108/200  train_loss=249.43  val_loss=74.57  train_acc=54.6%  val_acc=48.0%  lr=7.81e-07
#   no improvement (4/90)
# Epoch 109/200  train_loss=248.09  val_loss=74.27  train_acc=55.1%  val_acc=48.0%  lr=7.81e-07
#   no improvement (5/90)
# Epoch 110/200  train_loss=246.53  val_loss=74.39  train_acc=55.3%  val_acc=47.9%  lr=7.81e-07
#   no improvement (6/90)
# Epoch 111/200  train_loss=244.77  val_loss=74.49  train_acc=55.8%  val_acc=48.1%  lr=7.81e-07
#   no improvement (7/90)
# Epoch 112/200  train_loss=247.32  val_loss=74.49  train_acc=55.6%  val_acc=47.9%  lr=7.81e-07
#   no improvement (8/90)
# Epoch 113/200  train_loss=246.38  val_loss=74.62  train_acc=55.0%  val_acc=47.9%  lr=7.81e-07
#   no improvement (9/90)
# Epoch 114/200  train_loss=245.86  val_loss=73.56  train_acc=55.3%  val_acc=48.2%  lr=7.81e-07
#   no improvement (10/90)
# Epoch 115/200  train_loss=244.38  val_loss=75.08  train_acc=55.5%  val_acc=47.8%  lr=7.81e-07
#   no improvement (11/90)
# Epoch 116/200  train_loss=245.95  val_loss=73.98  train_acc=54.9%  val_acc=48.1%  lr=7.81e-07
#   no improvement (12/90)
# Epoch 117/200  train_loss=243.98  val_loss=74.24  train_acc=55.5%  val_acc=48.2%  lr=7.81e-07
#   no improvement (13/90)
# Epoch 118/200  train_loss=245.81  val_loss=74.29  train_acc=55.6%  val_acc=47.7%  lr=7.81e-07
#   no improvement (14/90)
# Epoch 119/200  train_loss=245.37  val_loss=74.18  train_acc=55.9%  val_acc=47.9%  lr=7.81e-07
#   no improvement (15/90)
# Epoch 120/200  train_loss=245.86  val_loss=74.84  train_acc=55.8%  val_acc=47.8%  lr=3.91e-07
#   no improvement (16/90)
# Epoch 121/200  train_loss=245.63  val_loss=73.90  train_acc=55.4%  val_acc=48.1%  lr=3.91e-07
#   no improvement (17/90)
# Epoch 122/200  train_loss=247.03  val_loss=74.18  train_acc=55.5%  val_acc=47.9%  lr=3.91e-07
#   no improvement (18/90)
# Epoch 123/200  train_loss=244.82  val_loss=74.50  train_acc=55.7%  val_acc=47.9%  lr=3.91e-07
#   no improvement (19/90)
# Epoch 124/200  train_loss=246.89  val_loss=74.35  train_acc=55.5%  val_acc=47.8%  lr=3.91e-07
#   no improvement (20/90)
# Epoch 125/200  train_loss=244.88  val_loss=73.76  train_acc=55.3%  val_acc=48.0%  lr=3.91e-07
#   no improvement (21/90)
# Epoch 126/200  train_loss=245.02  val_loss=73.84  train_acc=55.7%  val_acc=47.9%  lr=3.91e-07
#   no improvement (22/90)
# Epoch 127/200  train_loss=244.08  val_loss=73.82  train_acc=56.2%  val_acc=47.9%  lr=3.91e-07
#   no improvement (23/90)
# Epoch 128/200  train_loss=245.82  val_loss=74.07  train_acc=55.2%  val_acc=47.8%  lr=3.91e-07
#   no improvement (24/90)
# Epoch 129/200  train_loss=244.84  val_loss=74.07  train_acc=56.4%  val_acc=47.8%  lr=3.91e-07
#   no improvement (25/90)
# Epoch 130/200  train_loss=245.38  val_loss=74.61  train_acc=55.3%  val_acc=48.0%  lr=3.91e-07
#   no improvement (26/90)
# Epoch 131/200  train_loss=246.44  val_loss=74.16  train_acc=55.0%  val_acc=48.0%  lr=3.91e-07
#   no improvement (27/90)
# Epoch 132/200  train_loss=245.64  val_loss=74.23  train_acc=56.0%  val_acc=48.1%  lr=3.91e-07
#   no improvement (28/90)
# Epoch 133/200  train_loss=247.35  val_loss=74.12  train_acc=54.4%  val_acc=48.2%  lr=3.91e-07
#   no improvement (29/90)
# Epoch 134/200  train_loss=248.68  val_loss=73.82  train_acc=55.1%  val_acc=48.2%  lr=3.91e-07
#   no improvement (30/90)
# Epoch 135/200  train_loss=245.27  val_loss=73.42  train_acc=55.4%  val_acc=48.3%  lr=1.95e-07
#   no improvement (31/90)
# Epoch 136/200  train_loss=245.09  val_loss=75.50  train_acc=55.4%  val_acc=47.8%  lr=1.95e-07
#   no improvement (32/90)
# Epoch 137/200  train_loss=247.73  val_loss=75.00  train_acc=54.6%  val_acc=47.8%  lr=1.95e-07
#   no improvement (33/90)
# Epoch 138/200  train_loss=247.95  val_loss=73.81  train_acc=54.8%  val_acc=48.2%  lr=1.95e-07
#   no improvement (34/90)
# Epoch 139/200  train_loss=245.13  val_loss=74.40  train_acc=55.5%  val_acc=48.0%  lr=1.95e-07
#   no improvement (35/90)
# Epoch 140/200  train_loss=246.49  val_loss=74.51  train_acc=55.2%  val_acc=47.7%  lr=1.95e-07
#   no improvement (36/90)
# Epoch 141/200  train_loss=247.68  val_loss=74.63  train_acc=54.9%  val_acc=47.8%  lr=1.95e-07
#   no improvement (37/90)
# Epoch 142/200  train_loss=245.58  val_loss=74.62  train_acc=55.6%  val_acc=48.3%  lr=1.95e-07
#   no improvement (38/90)
# Epoch 143/200  train_loss=245.17  val_loss=74.09  train_acc=55.1%  val_acc=48.0%  lr=1.95e-07
#   no improvement (39/90)
# Epoch 144/200  train_loss=246.54  val_loss=74.42  train_acc=54.8%  val_acc=48.2%  lr=1.95e-07
#   no improvement (40/90)
# Epoch 145/200  train_loss=244.85  val_loss=73.58  train_acc=55.6%  val_acc=48.7%  lr=1.95e-07
#   no improvement (41/90)
# Epoch 146/200  train_loss=244.60  val_loss=74.41  train_acc=55.8%  val_acc=48.2%  lr=1.95e-07
#   no improvement (42/90)
# Epoch 147/200  train_loss=242.80  val_loss=74.03  train_acc=56.2%  val_acc=48.1%  lr=1.95e-07
#   no improvement (43/90)
# Epoch 148/200  train_loss=246.14  val_loss=74.57  train_acc=56.1%  val_acc=48.0%  lr=1.95e-07
#   no improvement (44/90)
# Epoch 149/200  train_loss=245.69  val_loss=73.99  train_acc=55.9%  val_acc=48.0%  lr=1.95e-07
#   no improvement (45/90)
# Epoch 150/200  train_loss=245.07  val_loss=74.41  train_acc=55.8%  val_acc=48.2%  lr=9.77e-08
#   no improvement (46/90)
# Epoch 151/200  train_loss=245.46  val_loss=74.42  train_acc=55.8%  val_acc=48.2%  lr=9.77e-08
#   no improvement (47/90)
# Epoch 152/200  train_loss=245.16  val_loss=74.26  train_acc=55.0%  val_acc=48.1%  lr=9.77e-08
#   no improvement (48/90)
# Epoch 153/200  train_loss=245.87  val_loss=74.44  train_acc=55.6%  val_acc=48.1%  lr=9.77e-08
#   no improvement (49/90)
# Epoch 154/200  train_loss=244.13  val_loss=74.26  train_acc=55.6%  val_acc=48.2%  lr=9.77e-08
#   no improvement (50/90)
# Epoch 155/200  train_loss=247.49  val_loss=75.11  train_acc=55.4%  val_acc=47.8%  lr=9.77e-08
#   no improvement (51/90)
# Epoch 156/200  train_loss=247.04  val_loss=74.56  train_acc=54.7%  val_acc=48.0%  lr=9.77e-08
#   no improvement (52/90)
# Epoch 157/200  train_loss=243.49  val_loss=74.70  train_acc=56.0%  val_acc=47.9%  lr=9.77e-08
#   no improvement (53/90)
# Epoch 158/200  train_loss=244.24  val_loss=74.20  train_acc=56.3%  val_acc=48.1%  lr=9.77e-08
#   no improvement (54/90)
# Epoch 159/200  train_loss=244.25  val_loss=74.46  train_acc=56.0%  val_acc=48.3%  lr=9.77e-08
#   no improvement (55/90)
# Epoch 160/200  train_loss=245.88  val_loss=74.12  train_acc=55.8%  val_acc=47.9%  lr=9.77e-08
#   no improvement (56/90)
# Epoch 161/200  train_loss=243.33  val_loss=74.19  train_acc=56.0%  val_acc=47.9%  lr=9.77e-08
#   no improvement (57/90)
# Epoch 162/200  train_loss=245.92  val_loss=73.94  train_acc=55.5%  val_acc=48.2%  lr=9.77e-08
#   no improvement (58/90)
# Epoch 163/200  train_loss=247.18  val_loss=74.21  train_acc=55.7%  val_acc=48.4%  lr=9.77e-08
#   no improvement (59/90)
# Epoch 164/200  train_loss=247.03  val_loss=73.87  train_acc=55.4%  val_acc=48.0%  lr=9.77e-08
#   no improvement (60/90)
# Epoch 165/200  train_loss=243.29  val_loss=74.29  train_acc=55.6%  val_acc=48.1%  lr=4.88e-08
#   no improvement (61/90)
# Epoch 166/200  train_loss=245.35  val_loss=74.55  train_acc=55.7%  val_acc=47.9%  lr=4.88e-08
#   no improvement (62/90)
# Epoch 167/200  train_loss=244.09  val_loss=74.36  train_acc=55.6%  val_acc=48.1%  lr=4.88e-08
#   no improvement (63/90)
# Epoch 168/200  train_loss=245.25  val_loss=73.57  train_acc=55.4%  val_acc=48.3%  lr=4.88e-08
#   no improvement (64/90)
# Epoch 169/200  train_loss=246.83  val_loss=74.39  train_acc=55.2%  val_acc=48.1%  lr=4.88e-08
#   no improvement (65/90)
# Epoch 170/200  train_loss=245.53  val_loss=75.14  train_acc=55.3%  val_acc=47.8%  lr=4.88e-08
#   no improvement (66/90)
# Epoch 171/200  train_loss=247.70  val_loss=74.21  train_acc=55.0%  val_acc=48.2%  lr=4.88e-08
#   no improvement (67/90)
# Epoch 172/200  train_loss=242.03  val_loss=75.06  train_acc=56.0%  val_acc=48.0%  lr=4.88e-08
#   no improvement (68/90)
# Epoch 173/200  train_loss=246.28  val_loss=74.18  train_acc=55.5%  val_acc=48.1%  lr=4.88e-08
#   no improvement (69/90)
# Epoch 174/200  train_loss=243.77  val_loss=74.83  train_acc=56.4%  val_acc=47.9%  lr=4.88e-08
#   no improvement (70/90)
# Epoch 175/200  train_loss=242.82  val_loss=73.51  train_acc=55.5%  val_acc=48.4%  lr=4.88e-08
#   no improvement (71/90)
# Epoch 176/200  train_loss=244.69  val_loss=73.70  train_acc=56.0%  val_acc=48.5%  lr=4.88e-08
#   no improvement (72/90)
# Epoch 177/200  train_loss=247.05  val_loss=73.97  train_acc=55.2%  val_acc=48.2%  lr=4.88e-08
#   no improvement (73/90)
# Epoch 178/200  train_loss=245.09  val_loss=74.38  train_acc=56.3%  val_acc=48.3%  lr=4.88e-08
#   no improvement (74/90)
# Epoch 179/200  train_loss=244.23  val_loss=73.78  train_acc=56.3%  val_acc=48.3%  lr=4.88e-08
#   no improvement (75/90)
# Epoch 180/200  train_loss=245.23  val_loss=74.20  train_acc=55.8%  val_acc=48.1%  lr=2.44e-08
#   no improvement (76/90)
# Epoch 181/200  train_loss=246.91  val_loss=74.90  train_acc=55.2%  val_acc=48.0%  lr=2.44e-08
#   no improvement (77/90)
# Epoch 182/200  train_loss=245.72  val_loss=73.65  train_acc=55.0%  val_acc=48.6%  lr=2.44e-08
#   no improvement (78/90)
# Epoch 183/200  train_loss=244.36  val_loss=73.90  train_acc=55.4%  val_acc=48.2%  lr=2.44e-08
#   no improvement (79/90)
# Epoch 184/200  train_loss=246.81  val_loss=75.05  train_acc=55.5%  val_acc=48.0%  lr=2.44e-08
#   no improvement (80/90)
# Epoch 185/200  train_loss=244.05  val_loss=74.38  train_acc=55.4%  val_acc=48.2%  lr=2.44e-08
#   no improvement (81/90)
# Epoch 186/200  train_loss=246.40  val_loss=74.11  train_acc=55.7%  val_acc=48.1%  lr=2.44e-08
#   no improvement (82/90)
# Epoch 187/200  train_loss=246.44  val_loss=74.75  train_acc=55.5%  val_acc=48.0%  lr=2.44e-08
#   no improvement (83/90)
# Epoch 188/200  train_loss=247.73  val_loss=74.69  train_acc=55.1%  val_acc=48.1%  lr=2.44e-08
#   no improvement (84/90)
# Epoch 189/200  train_loss=245.21  val_loss=74.27  train_acc=55.7%  val_acc=48.0%  lr=2.44e-08
#   no improvement (85/90)
# Epoch 190/200  train_loss=244.18  val_loss=73.42  train_acc=55.4%  val_acc=48.5%  lr=2.44e-08
#   no improvement (86/90)
# Epoch 191/200  train_loss=245.60  val_loss=73.67  train_acc=55.6%  val_acc=48.5%  lr=2.44e-08
#   no improvement (87/90)
# Epoch 192/200  train_loss=245.50  val_loss=74.97  train_acc=55.6%  val_acc=47.8%  lr=2.44e-08
#   no improvement (88/90)
# Epoch 193/200  train_loss=246.97  val_loss=73.38  train_acc=55.4%  val_acc=48.6%  lr=2.44e-08
#   no improvement (89/90)
# Epoch 194/200  train_loss=244.42  val_loss=73.90  train_acc=56.2%  val_acc=48.1%  lr=2.44e-08
#   no improvement (90/90)
#
#  Early stopping at epoch 194 — best val_loss=73.3046
#
#  Best model restored from /kaggle/working/eeg_model_best.pth
# Model saved → /kaggle/working/eeg_model.pth

# %%
label_names = ["Left fist", "Right fist", "Both fists", "Both feet"]
evaluate(model, val_loader, device, label_names=label_names)

plot_confusion_matrix(model, val_loader, device, label_names)
plt.savefig('/kaggle/working/confusion_matrix.png')
# Out:
# Val Accuracy: 48.45%
#
#               precision    recall  f1-score   support
#
#    Left fist       0.44      0.65      0.53       496
#   Right fist       0.44      0.51      0.48       488
#   Both fists       0.55      0.33      0.41       497
#    Both feet       0.59      0.44      0.50       488
#
#     accuracy                           0.48      1969
#    macro avg       0.50      0.48      0.48      1969
# weighted avg       0.50      0.48      0.48      1969

# %%
def get_device():
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")

DEVICE = get_device()

# %%
def model_tuning(model, num_classes: int = 4, device: torch.device = None) -> tuple:
    device = device or DEVICE

    for p in model.parameters():
        p.requires_grad = False

    for p in model.classifier.parameters():
        p.requires_grad = True

    model.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.ELU(),
            nn.Linear(256, 128),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ELU(),
            nn.Linear(64, num_classes)
    )
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=5e-3,
        weight_decay=1e-4
    )
    for param_group in optimizer.param_groups:
        param_group['lr'] = 3e-3
    scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer, step_size=20, gamma=0.7  
        )

    total     = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n  Params: {total:,} total  |  {trainable:,} trainable "
          f"({100 * trainable / total:.1f}%)")

    return model.to(device), optimizer, scheduler

# %%
tuned_model = ATCNet_LSTM(n_channels=44, num_classes=4)
tuned_model.load_state_dict(
    torch.load('/kaggle/working/eeg_model_best.pth', weights_only=False),
    strict=False
)

tuned_model, optimizer_ft, scheduler_ft = model_tuning(tuned_model)
# Out:
#   Params: 2,470,484 total  |  172,740 trainable (7.0%)

# %%
def augment_eeg(X, noise_std=0.05, shift_max=20):
    X_aug = X.copy()
    N, C, T = X_aug.shape

    X_aug += np.random.randn(*X_aug.shape).astype(np.float32) * noise_std

    shifts = np.random.randint(-shift_max, shift_max, size=N)
    for i, s in enumerate(shifts):
        X_aug[i] = np.roll(X_aug[i], s, axis=-1)

    return X_aug

# %%
for f in ["/kaggle/working/cache_train.npy", "/kaggle/working/cache_val.npy"]:
    if os.path.exists(f):
        os.remove(f)
        print(f"Deleted old cache: {f}")

builder_tune = EEGDatasetBuilder(DATA_PATH)
X, y_raw, ch_names, subjects = builder_tune.build(tune=1)
 
y, label_encoder = encode_labels(y_raw)
num_classes      = len(label_encoder.classes_)
class_counts = np.bincount(y)
 
# Data augmentation 
X_aug = augment_eeg(X, noise_std=0.03, shift_max=15)
X_all = np.concatenate([X, X_aug], axis=0)
y_all = np.concatenate([y, y], axis=0)
 
print(f"After augmentation: X={X_all.shape}, y={y_all.shape}")
 
train_idx, val_idx = train_test_split(
    np.arange(len(X_all)),
    test_size=0.2,    
    random_state=42,
    stratify=y_all
)
 
X_train_tuning, X_val_tuning = X_all[::], X_all[val_idx]
y_train_tuning, y_val_tuning = y_all[::], y_all[val_idx]
 
train_ds_tuning = EEGTorchDataset(X_train_tuning, y_train_tuning)
val_ds_tuning   = EEGTorchDataset(X_val_tuning,   y_val_tuning) 
 
pin     = torch.cuda.is_available()
sampler = make_weighted_sampler(y_train_tuning)
 
train_loader_tuning = DataLoader(train_ds_tuning, batch_size=64, sampler=sampler,
                                  num_workers=2, pin_memory=pin)
val_loader_tuning   = DataLoader(val_ds_tuning,   batch_size=64, shuffle=False,
                                  num_workers=2, pin_memory=pin)
# Out:
# Total files: 1526  |  After run filter: 654
# Total files: 1526  |  After run filter: 654
# Skipped: 0 / 12
# X shape  : (180, 44, 641)  dtype: float32
# y shape  : (180,)  classes: [0 1 2 3]
# Per class: [46 44 46 44]
# Classes: [0 1 2 3]  →  [0 1 2 3]
# After augmentation: X=(360, 44, 641), y=(360,)
# Class counts: [92 88 92 88]

# %%
train(tuned_model, train_loader_tuning, val_loader_tuning, device, optimizer_ft, scheduler_ft, epochs=70, class_counts=class_counts, patience=50, save_path='/kaggle/working/best_tuned_model.pth')

label_names = ["Left fist", "Right fist", "Both fists", "Both feet"]
evaluate(tuned_model, val_loader_tuning, device, label_names=label_names)

save_model(tuned_model, num_classes, label_encoder, ch_names, matched_ch)
# Out:
# Using weighted loss: [0.24444443 0.25555554 0.24444443 0.25555554]
# Epoch 01/70  train_loss=7.44  val_loss=2.25  train_acc=39.2%  val_acc=41.7%  lr=2.10e-03
#   val_loss improved → best model saved
# Epoch 02/70  train_loss=7.15  val_loss=2.39  train_acc=45.0%  val_acc=45.8%  lr=2.10e-03
#   no improvement (1/50)
# Epoch 03/70  train_loss=6.91  val_loss=2.25  train_acc=44.2%  val_acc=45.8%  lr=2.10e-03
#   val_loss improved → best model saved
# Epoch 04/70  train_loss=7.17  val_loss=2.17  train_acc=45.0%  val_acc=40.3%  lr=2.10e-03
#   val_loss improved → best model saved
# Epoch 05/70  train_loss=7.19  val_loss=2.31  train_acc=41.1%  val_acc=43.1%  lr=2.10e-03
#   no improvement (1/50)
# Epoch 06/70  train_loss=7.38  val_loss=2.28  train_acc=38.9%  val_acc=45.8%  lr=2.10e-03
#   no improvement (2/50)
# Epoch 07/70  train_loss=7.21  val_loss=2.16  train_acc=40.3%  val_acc=47.2%  lr=2.10e-03
#   val_loss improved → best model saved
# Epoch 08/70  train_loss=7.41  val_loss=2.19  train_acc=40.8%  val_acc=40.3%  lr=2.10e-03
#   no improvement (1/50)
# Epoch 09/70  train_loss=6.81  val_loss=2.19  train_acc=47.8%  val_acc=44.4%  lr=2.10e-03
#   no improvement (2/50)
# Epoch 10/70  train_loss=7.28  val_loss=2.39  train_acc=38.9%  val_acc=41.7%  lr=1.47e-03
#   no improvement (3/50)
# Epoch 11/70  train_loss=7.25  val_loss=2.42  train_acc=41.4%  val_acc=44.4%  lr=1.47e-03
#   no improvement (4/50)
# Epoch 12/70  train_loss=7.02  val_loss=2.27  train_acc=41.4%  val_acc=48.6%  lr=1.47e-03
#   no improvement (5/50)
# Epoch 13/70  train_loss=7.04  val_loss=2.29  train_acc=45.8%  val_acc=43.1%  lr=1.47e-03
#   no improvement (6/50)
# Epoch 14/70  train_loss=7.16  val_loss=2.31  train_acc=41.1%  val_acc=44.4%  lr=1.47e-03
#   no improvement (7/50)
# Epoch 15/70  train_loss=7.23  val_loss=2.34  train_acc=43.3%  val_acc=47.2%  lr=1.47e-03
#   no improvement (8/50)
# Epoch 16/70  train_loss=7.29  val_loss=2.43  train_acc=41.7%  val_acc=44.4%  lr=1.47e-03
#   no improvement (9/50)
# Epoch 17/70  train_loss=6.96  val_loss=2.29  train_acc=46.4%  val_acc=43.1%  lr=1.47e-03
#   no improvement (10/50)
# Epoch 18/70  train_loss=7.39  val_loss=2.27  train_acc=39.7%  val_acc=44.4%  lr=1.47e-03
#   no improvement (11/50)
# Epoch 19/70  train_loss=6.54  val_loss=2.35  train_acc=48.1%  val_acc=43.1%  lr=1.47e-03
#   no improvement (12/50)
# Epoch 20/70  train_loss=7.04  val_loss=2.31  train_acc=41.1%  val_acc=41.7%  lr=1.47e-03
#   no improvement (13/50)
# Epoch 21/70  train_loss=7.18  val_loss=2.33  train_acc=41.4%  val_acc=43.1%  lr=1.47e-03
#   no improvement (14/50)
# Epoch 22/70  train_loss=7.33  val_loss=2.38  train_acc=38.9%  val_acc=44.4%  lr=1.47e-03
#   no improvement (15/50)
# Epoch 23/70  train_loss=7.13  val_loss=2.31  train_acc=45.0%  val_acc=44.4%  lr=1.47e-03
#   no improvement (16/50)
# Epoch 24/70  train_loss=6.92  val_loss=2.19  train_acc=43.1%  val_acc=47.2%  lr=1.47e-03
#   no improvement (17/50)
# Epoch 25/70  train_loss=6.47  val_loss=2.23  train_acc=49.2%  val_acc=43.1%  lr=1.47e-03
#   no improvement (18/50)
# Epoch 26/70  train_loss=7.25  val_loss=2.35  train_acc=43.1%  val_acc=45.8%  lr=1.47e-03
#   no improvement (19/50)
# Epoch 27/70  train_loss=7.36  val_loss=2.45  train_acc=41.1%  val_acc=45.8%  lr=1.47e-03
#   no improvement (20/50)
# Epoch 28/70  train_loss=7.31  val_loss=2.41  train_acc=42.2%  val_acc=48.6%  lr=1.47e-03
#   no improvement (21/50)
# Epoch 29/70  train_loss=7.36  val_loss=2.27  train_acc=39.7%  val_acc=47.2%  lr=1.47e-03
#   no improvement (22/50)
# Epoch 30/70  train_loss=7.19  val_loss=2.16  train_acc=41.9%  val_acc=44.4%  lr=1.03e-03
#   no improvement (23/50)
# Epoch 31/70  train_loss=6.98  val_loss=2.19  train_acc=43.9%  val_acc=45.8%  lr=1.03e-03
#   no improvement (24/50)
# Epoch 32/70  train_loss=7.00  val_loss=2.29  train_acc=45.0%  val_acc=47.2%  lr=1.03e-03
#   no improvement (25/50)
# Epoch 33/70  train_loss=6.89  val_loss=2.34  train_acc=46.1%  val_acc=45.8%  lr=1.03e-03
#   no improvement (26/50)
# Epoch 34/70  train_loss=7.06  val_loss=2.37  train_acc=42.5%  val_acc=45.8%  lr=1.03e-03
#   no improvement (27/50)
# Epoch 35/70  train_loss=7.22  val_loss=2.32  train_acc=41.4%  val_acc=45.8%  lr=1.03e-03
#   no improvement (28/50)
# Epoch 36/70  train_loss=7.13  val_loss=2.27  train_acc=43.6%  val_acc=45.8%  lr=1.03e-03
#   no improvement (29/50)
# Epoch 37/70  train_loss=7.04  val_loss=2.21  train_acc=41.4%  val_acc=43.1%  lr=1.03e-03
#   no improvement (30/50)
# Epoch 38/70  train_loss=6.95  val_loss=2.15  train_acc=44.7%  val_acc=51.4%  lr=1.03e-03
#   val_loss improved → best model saved
# Epoch 39/70  train_loss=7.13  val_loss=2.13  train_acc=37.8%  val_acc=52.8%  lr=1.03e-03
#   val_loss improved → best model saved
# Epoch 40/70  train_loss=6.94  val_loss=2.21  train_acc=40.8%  val_acc=48.6%  lr=1.03e-03
#   no improvement (1/50)
# Epoch 41/70  train_loss=7.16  val_loss=2.31  train_acc=41.7%  val_acc=44.4%  lr=1.03e-03
#   no improvement (2/50)
# Epoch 42/70  train_loss=6.71  val_loss=2.41  train_acc=46.4%  val_acc=47.2%  lr=1.03e-03
#   no improvement (3/50)
# Epoch 43/70  train_loss=7.26  val_loss=2.34  train_acc=41.1%  val_acc=45.8%  lr=1.03e-03
#   no improvement (4/50)
# Epoch 44/70  train_loss=6.60  val_loss=2.26  train_acc=50.3%  val_acc=48.6%  lr=1.03e-03
#   no improvement (5/50)
# Epoch 45/70  train_loss=6.85  val_loss=2.21  train_acc=48.3%  val_acc=50.0%  lr=1.03e-03
#   no improvement (6/50)
# Epoch 46/70  train_loss=7.63  val_loss=2.21  train_acc=37.8%  val_acc=43.1%  lr=1.03e-03
#   no improvement (7/50)
# Epoch 47/70  train_loss=6.99  val_loss=2.26  train_acc=46.9%  val_acc=50.0%  lr=1.03e-03
#   no improvement (8/50)
# Epoch 48/70  train_loss=7.31  val_loss=2.26  train_acc=40.8%  val_acc=48.6%  lr=1.03e-03
#   no improvement (9/50)
# Epoch 49/70  train_loss=7.23  val_loss=2.24  train_acc=43.1%  val_acc=48.6%  lr=1.03e-03
#   no improvement (10/50)
# Epoch 50/70  train_loss=7.08  val_loss=2.19  train_acc=41.4%  val_acc=48.6%  lr=7.20e-04
#   no improvement (11/50)
# Epoch 51/70  train_loss=6.95  val_loss=2.20  train_acc=42.8%  val_acc=50.0%  lr=7.20e-04
#   no improvement (12/50)
# Epoch 52/70  train_loss=6.48  val_loss=2.24  train_acc=47.8%  val_acc=45.8%  lr=7.20e-04
#   no improvement (13/50)
# Epoch 53/70  train_loss=6.99  val_loss=2.25  train_acc=45.8%  val_acc=44.4%  lr=7.20e-04
#   no improvement (14/50)
# Epoch 54/70  train_loss=6.56  val_loss=2.24  train_acc=47.8%  val_acc=45.8%  lr=7.20e-04
#   no improvement (15/50)
# Epoch 55/70  train_loss=7.28  val_loss=2.22  train_acc=45.0%  val_acc=47.2%  lr=7.20e-04
#   no improvement (16/50)
# Epoch 56/70  train_loss=7.21  val_loss=2.24  train_acc=41.1%  val_acc=48.6%  lr=7.20e-04
#   no improvement (17/50)
# Epoch 57/70  train_loss=6.95  val_loss=2.24  train_acc=44.2%  val_acc=52.8%  lr=7.20e-04
#   no improvement (18/50)
# Epoch 58/70  train_loss=7.13  val_loss=2.21  train_acc=43.3%  val_acc=51.4%  lr=7.20e-04
#   no improvement (19/50)
# Epoch 59/70  train_loss=6.58  val_loss=2.25  train_acc=48.3%  val_acc=44.4%  lr=7.20e-04
#   no improvement (20/50)
# Epoch 60/70  train_loss=6.91  val_loss=2.25  train_acc=45.6%  val_acc=50.0%  lr=7.20e-04
#   no improvement (21/50)
# Epoch 61/70  train_loss=6.85  val_loss=2.28  train_acc=45.0%  val_acc=48.6%  lr=7.20e-04
#   no improvement (22/50)
# Epoch 62/70  train_loss=6.60  val_loss=2.28  train_acc=46.7%  val_acc=44.4%  lr=7.20e-04
#   no improvement (23/50)
# Epoch 63/70  train_loss=6.60  val_loss=2.24  train_acc=46.1%  val_acc=44.4%  lr=7.20e-04
#   no improvement (24/50)
# Epoch 64/70  train_loss=6.82  val_loss=2.22  train_acc=46.1%  val_acc=45.8%  lr=7.20e-04
#   no improvement (25/50)
# Epoch 65/70  train_loss=7.23  val_loss=2.25  train_acc=40.6%  val_acc=40.3%  lr=7.20e-04
#   no improvement (26/50)
# Epoch 66/70  train_loss=6.87  val_loss=2.22  train_acc=42.8%  val_acc=44.4%  lr=7.20e-04
#   no improvement (27/50)
# Epoch 67/70  train_loss=7.31  val_loss=2.24  train_acc=38.3%  val_acc=54.2%  lr=7.20e-04
#   no improvement (28/50)
# Epoch 68/70  train_loss=7.04  val_loss=2.23  train_acc=42.8%  val_acc=51.4%  lr=7.20e-04
#   no improvement (29/50)
# Epoch 69/70  train_loss=7.13  val_loss=2.13  train_acc=44.2%  val_acc=47.2%  lr=7.20e-04
#   no improvement (30/50)
# Epoch 70/70  train_loss=7.13  val_loss=2.14  train_acc=41.7%  val_acc=48.6%  lr=5.04e-04
#   no improvement (31/50)
#
#  Best model restored from /kaggle/working/best_tuned_model.pth
#
# Val Accuracy: 52.78%
#
#               precision    recall  f1-score   support
#
#    Left fist       0.48      0.61      0.54        18
#   Right fist       0.75      0.33      0.46        18
#   Both fists       0.44      0.78      0.56        18
#    Both feet       0.78      0.39      0.52        18
#
#     accuracy                           0.53        72
#    macro avg       0.61      0.53      0.52        72
# weighted avg       0.61      0.53      0.52        72
#
# Model saved → /kaggle/working/eeg_model.pth

# %%
plot_confusion_matrix(model, val_loader_tuning, device, label_names)
plt.savefig('/kaggle/working/confusion_matrix_tuning.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/2599380763.py in <cell line: 0>()
# ----> 1 plot_confusion_matrix(model, val_loader_tuning, device, label_names)
#       2 plt.savefig('/kaggle/working/confusion_matrix_tuning.png')
#
# NameError: name 'plot_confusion_matrix' is not defined
