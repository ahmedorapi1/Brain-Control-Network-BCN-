# %%
import os
import glob
import numpy as np
import math
import mne
from scipy.interpolate import griddata
from matplotlib import colormaps
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupShuffleSplit
from sklearn.model_selection import train_test_split

# %%
#   0 = Left fist   (R03,R07,R11 → T1)
#   1 = Right fist  (R03,R07,R11 → T2)
#   2 = Both fists  (R04,R08,R12 → T1)
#   3 = Both feet   (R04,R08,R12 → T2)
class EEGDatasetBuilder:
    def __init__(self, data_path, target_sfreq=160):
        self.data_path    = data_path
        self.target_sfreq = target_sfreq
        self.target_runs  = ['R03', 'R04', 'R07', 'R08', 'R11', 'R12']
        self._last_ch_names = None

        self.target_channels_clean = [
            "FC5","FC3","FC1","FCZ","FC2","FC4","FC6",
            "C5","C3","C1","CZ","C2","C4","C6",
            "CP5","CP3","CP1","CPZ","CP2","CP4","CP6",
            "F7","F5","F3","F1","FZ","F2","F4","F6","F8",
            "T7","T8",
            "P7","P5","P3","P1","PZ","P2","P4","P6","P8",
            "O1","OZ","O2"
        ]
    def load_subject(self):
        all_files = sorted(glob(
            os.path.join(self.data_path, "*", "*.edf")
        ))
        filtered = [
            f for f in all_files
            if any(run in os.path.basename(f) for run in self.target_runs)
        ]
        print(f"Total files: {len(all_files)}  |  After run filter: {len(filtered)}")
        return filtered
        
    def load_files(self):
        all_files = sorted(glob.glob(
            os.path.join(self.data_path, "*", "*.edf")
        ))
        filtered = [
            f for f in all_files
            if any(run in os.path.basename(f) for run in self.target_runs)
        ]
        print(f"Total files: {len(all_files)}  |  After run filter: {len(filtered)}")
        return filtered

    @staticmethod
    def _clean_ch_names(raw):
        rename_dict = {ch: ch.rstrip('.').upper() for ch in raw.ch_names}
        raw.rename_channels(rename_dict)
        return raw

    @staticmethod
    def _annotation_to_label(description, basename):
        is_fist_run = any(r in basename for r in ['R03', 'R07', 'R11'])
 
        if description == 'T0':
            return -1
        elif description == 'T1':
            return 0 if is_fist_run else 2   # left fist | both fists
        elif description == 'T2':
            return 1 if is_fist_run else 3   # right fist | both feet
        return -1
        
    def get_subjects(self):
        files = self.load_files()
        subjects = sorted(list({
            os.path.basename(f).split("R")[0]
            for f in files}))
        return subjects
    
    def build(self, tune=0):
        X, y     = [], []
        skipped  = 0
        last_raw = None
 
        all_subjects = self.get_subjects()
        tune_subject = set(all_subjects[:1])
        all_files    = self.load_files()
 
        if tune == 1:
            edf_files         = [f for f in all_files
                                  if os.path.basename(f).split("R")[0] in tune_subject]
            excluded_subjects = set()
        else:
            edf_files         = all_files
            excluded_subjects = tune_subject
 
        subjects = []
        for file in edf_files:
            subject_id = os.path.basename(file).split("R")[0]
            if subject_id in excluded_subjects:
                continue
            try:
                raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
                raw = self._clean_ch_names(raw)
 
                if raw.info['sfreq'] != self.target_sfreq:
                    raw.resample(self.target_sfreq, verbose=False)
 
                available = [ch for ch in self.target_channels_clean
                             if ch in raw.ch_names]
                if len(available) == 0:
                    skipped += 1
                    continue
                raw.pick(available, verbose=False)
 
                raw.filter(4., 35., verbose=False)
 
                events, event_id = mne.events_from_annotations(raw, verbose=False)
                if len(events) == 0:
                    skipped += 1
                    continue
 
                tmax   = 4.0
                epochs = mne.Epochs(
                    raw, events, event_id=event_id,
                    tmin=0.0, tmax=tmax,
                    baseline=None, preload=True,
                    reject_by_annotation=False,
                    verbose=False
                )
 
                data       = epochs.get_data()
                raw_labels = epochs.events[:, -1]
                descriptions = [
                    list(event_id.keys())[list(event_id.values()).index(l)]
                    for l in raw_labels
                ]
 
                basename = os.path.basename(file)
                labels   = np.array([
                    self._annotation_to_label(d, basename)
                    for d in descriptions
                ])
 
                valid  = labels >= 0
                data   = data[valid]
                labels = labels[valid]
 
                if len(data) == 0:
                    skipped += 1
                    continue
 
                expected_T = int(tmax * self.target_sfreq) + 1
                if data.shape[2] > expected_T:
                    data = data[:, :, :expected_T]
                elif data.shape[2] < expected_T:
                    pad  = expected_T - data.shape[2]
                    data = np.pad(data, ((0,0),(0,0),(0,pad)))
 
                X.append(data.astype(np.float32))
                y.append(labels)
                last_raw = raw
                subjects.append(np.array([subject_id] * len(labels)))
 
            except Exception as e:
                print(f"Skip: {os.path.basename(file)}  →  {e}")
                skipped += 1
                continue
 
        print(f"Skipped: {skipped} / {len(edf_files)}")
 
        if len(X) == 0:
            raise ValueError("No valid epochs found")
 
        X = np.concatenate(X, axis=0)
        y = np.concatenate(y, axis=0)
        self._last_ch_names = list(last_raw.ch_names)
 
        print(f"X shape  : {X.shape}  dtype: {X.dtype}")
        print(f"y shape  : {y.shape}  classes: {np.unique(y)}")
        print(f"Per class: {np.bincount(y)}")
        subjects = np.concatenate(subjects)
        return X, y, self._last_ch_names, subjects

# %%
def encode_labels(y):
    le    = LabelEncoder()
    y_enc = le.fit_transform(y).astype(np.int64)
    print(f"Classes: {le.classes_}  →  {np.unique(y_enc)}")
    return y_enc, le

# %%
# 3. ELECTRODE POSITIONS
def get_electrode_positions(ch_names):
    montage   = mne.channels.make_standard_montage("standard_1020")
    pos       = montage.get_positions()['ch_pos']
    pos_upper = {k.upper(): v for k, v in pos.items()}

    matched_ch     = []
    matched_coords = []
    for ch in ch_names:
        if ch.upper() in pos_upper:
            matched_ch.append(ch)
            matched_coords.append(pos_upper[ch.upper()])

    if len(matched_ch) == 0:
        raise ValueError("No channels matched montage positions")

    coords = np.array(matched_coords)
    x_sel  = coords[:, 0]
    y_sel  = coords[:, 1]

    x_norm = (x_sel - x_sel.min()) / (x_sel.max() - x_sel.min()) * 2 - 1
    y_norm = (y_sel - y_sel.min()) / (y_sel.max() - y_sel.min()) * 2 - 1

    xi, yi = np.meshgrid(np.linspace(-1, 1, 32), np.linspace(-1, 1, 32))

    print(f"Electrode positions: {len(matched_ch)} / {len(ch_names)} matched")
    return x_norm, y_norm, xi, yi, matched_ch

# %%
class EEGTorchDataset(Dataset):
    """
    X: (N, C, T)  float32
    y: (N,)       int64
    Output: (C, T) tensor مباشرة للموديل
    """
    def __init__(self, X, y):
        # Normalize كل sample على حدة
        mean = X.mean(axis=(1, 2), keepdims=True)
        std  = X.std(axis=(1, 2),  keepdims=True) + 1e-8
        self.X = ((X - mean) / std).astype(np.float32)
        self.y = y.astype(np.int64)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.X[idx]),   # (C, T)
            torch.tensor(self.y[idx])
        )

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    if torch.backends.mps.is_available():
        return torch.device("mps")
    return torch.device("cpu")

# %%
def make_weighted_sampler(y_train):
    """
    WeightedRandomSampler عشان نعالج الـ class imbalance
    """
    class_counts  = np.bincount(y_train)
    sample_weights = np.array([1.0 / class_counts[y] for y in y_train])
    sampler = WeightedRandomSampler(
        weights     = torch.tensor(sample_weights, dtype=torch.float32),
        num_samples = len(sample_weights),
        replacement = True
    )
    print(f"Class counts: {class_counts}")
    return sampler

# %%
def train(model, loader, val_loader, device, optimizer_ft=None, scheduler_ft=None, epochs=50, class_counts=None,
          patience=5, save_path='/kaggle/working/eeg_model_best.pth'):
 
    model.to(device)
 
    if class_counts is not None:
        weights = 1.0 / torch.tensor(class_counts, dtype=torch.float32)
        weights = (weights / weights.sum()).to(device)
        loss_fn = nn.CrossEntropyLoss(weight=weights)
        print(f"Using weighted loss: {weights.cpu().numpy()}")
    else:
         loss_fn = nn.CrossEntropyLoss()
                
    if optimizer_ft is not None:
        optimizer = optimizer_ft
    else:
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=1e-4,         
            weight_decay=1e-4  
        )
    
    if scheduler_ft is not None:
        scheduler = scheduler_ft
    else:
        scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer, step_size=25, gamma=0.7  
        )
  
    best_val_loss     = float('inf')
    epochs_no_improve = 0
 
    for epoch in range(epochs):
        # ── Training 
        model.train()
        total_loss, correct, total = 0.0, 0, 0
 
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
 
            optimizer.zero_grad()
            out  = model(X_batch)
            loss = loss_fn(out, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            correct    += (out.argmax(1) == y_batch).sum().item()
            total      += len(y_batch)
 
        # ── Validation 
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                out      = model(X_batch)
                val_loss += loss_fn(out, y_batch).item()
                val_correct += (out.argmax(1) == y_batch).sum().item()
                val_total   += len(y_batch)
        scheduler.step()
         
 
        current_lr = optimizer.param_groups[0]['lr']   
    
        print(f"Epoch {epoch+1:02d}/{epochs}  "
              f"train_loss={total_loss:.2f}  "
              f"val_loss={val_loss:.2f}  "
              f"train_acc={correct/total*100:.1f}%  "
              f"val_acc={val_correct/val_total*100:.1f}%  "  
              f"lr={current_lr:.2e}")
 
        if val_loss < best_val_loss:
            best_val_loss     = val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
            print(f"  val_loss improved → best model saved")
        else:
            epochs_no_improve += 1
            print(f"  no improvement ({epochs_no_improve}/{patience})")
            if epochs_no_improve >= patience:
                print(f"\n Early stopping at epoch {epoch+1} "
                      f"— best val_loss={best_val_loss:.4f}")
                break
    if os.path.exists(save_path):
        model.load_state_dict(torch.load(save_path, weights_only=False))
        print(f"\n Best model restored from {save_path}")
    else:
        print(f"\n No saved model found — keeping current weights")

# %%
def evaluate(model, loader, device, label_names=None):
    model.eval()
    all_preds, all_true = [], []
    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            out     = model(X_batch)
            preds   = torch.argmax(out, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_true.extend(y_batch.numpy())

    all_preds = np.array(all_preds)
    all_true  = np.array(all_true)
    acc       = (all_preds == all_true).mean() * 100
    print(f"\nVal Accuracy: {acc:.2f}%\n")

    if label_names is None:
        num_cls    = len(np.unique(all_true))
        label_names = [f"Class {i}" for i in range(num_cls)]

    report = classification_report(all_true, all_preds, target_names=label_names)

    with open('/kaggle/working/report.txt', 'w') as f:
        f.write(report)
    
    print(report)
    return all_preds, all_true

# %%
def plot_confusion_matrix(model, loader, device, label_names=None):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(device)
            out     = model(X_batch)
            preds   = out.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y_batch.numpy())

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(
        confusion_matrix=cm,
        display_labels=label_names or list(range(cm.shape[0]))
    )

    fig, ax = plt.subplots(figsize=(6, 5))
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title("Confusion Matrix")
    plt.tight_layout()
    plt.show()

# %%
def save_model(model, num_classes, label_encoder, ch_names, matched_ch,
               path='/kaggle/working/eeg_model.pth'):
    torch.save({
        'model_state_dict': model.state_dict(),
        'num_classes':      num_classes,
        'label_classes':    label_encoder.classes_,
        'ch_names':         ch_names,
        'matched_ch':       matched_ch,
    }, path)
    print(f"Model saved → {path}")

# %%
def load_model(path='/kaggle/working/eeg_model.pth'):
    checkpoint = torch.load(path, map_location='cpu', weights_only=False)
    model      = CNN_LSTM(num_classes=checkpoint['num_classes'])  
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    print(f"Model loaded  classes={checkpoint['label_classes']}")
    return model, checkpoint

# %%
class ChannelAttention(nn.Module):
    def __init__(self, n_channels: int, reduction: int = 4):
        super().__init__()
        reduced = max(1, n_channels // reduction)

        self.squeeze = nn.AdaptiveAvgPool1d(1)  
        self.excitation = nn.Sequential(
            nn.Linear(n_channels, reduced),
            nn.ReLU(inplace=True),
            nn.Linear(reduced, n_channels),
            nn.Sigmoid()  
        )

    def forward(self, x):
        B, C, T = x.shape

        z = self.squeeze(x).view(B, C)       
        w = self.excitation(z).view(B, C, 1)  

        return x * w  


class ATCNet_LSTM(nn.Module):
    def __init__(self, n_channels=44, n_times=641,
                 num_classes=4, hidden=256, ca_reduction=4):
        super().__init__()

        
        self.channel_attention = ChannelAttention(n_channels, reduction=ca_reduction)

        self.spatial = nn.Sequential(
            nn.Conv2d(1, 16, (n_channels, 1)),
            nn.BatchNorm2d(16),
            nn.ELU(),
            nn.Dropout(0.25)
        )

        self.temporal = nn.Sequential(
            nn.Conv1d(16, 32, kernel_size=25, padding=12),
            nn.BatchNorm1d(32),
            nn.ELU(),
            nn.AvgPool1d(8),
            nn.Dropout(0.25),
            nn.Conv1d(32, 64, kernel_size=15, padding=7),
            nn.BatchNorm1d(64),
            nn.ELU(),
            nn.AvgPool1d(4),
            nn.Dropout(0.25)
        )

        self.attention = nn.MultiheadAttention(
            embed_dim=64,
            num_heads=8,
            dropout=0.25,
            batch_first=True
        )
        self.attn_norm = nn.LayerNorm(64)

        self.lstm = nn.LSTM(
            input_size=64,
            hidden_size=hidden,
            num_layers=2,
            batch_first=True,
            dropout=0.3,
            bidirectional=True
        )

        self.classifier = nn.Sequential(
            nn.Linear(hidden * 2, 256),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        B = x.size(0)


        x = self.channel_attention(x)   

        x = x.unsqueeze(1)              # (B, 1, C, T)
        x = self.spatial(x)             # (B, 16, 1, T)
        x = x.squeeze(2)                # (B, 16, T)

        x = self.temporal(x)            # (B, 64, T')

        x = x.permute(0, 2, 1)          # (B, T', 64)
        attn_out, _ = self.attention(x, x, x)
        x = self.attn_norm(x + attn_out)

        # LSTM
        out, _ = self.lstm(x)
        out = out[:, -1, :]

        return self.classifier(out)

# %%
DATA_PATH = "/kaggle/input/datasets/brianleung2020/eeg-motor-movementimagery-dataset/files"

for f in ["/kaggle/working/cache_train.npy", "/kaggle/working/cache_val.npy"]:
    if os.path.exists(f):
        os.remove(f)
        print(f"Deleted old cache: {f}")

builder = EEGDatasetBuilder(DATA_PATH)


X, y_raw, ch_names, subjects  = builder.build()
y, label_encoder = encode_labels(y_raw)
num_classes = len(label_encoder.classes_)   # 4

x_sel, y_sel, xi, yi, matched_ch = get_electrode_positions(ch_names)

ch_idx = [ch_names.index(ch) for ch in matched_ch]
X = X[:, ch_idx, :]

print(f"\nFinal X : {X.shape}")
print(f"Classes : {num_classes}  per class: {np.bincount(y)}")

gss = GroupShuffleSplit(test_size=0.20, random_state=42)

train_idx, val_idx = next(gss.split(X, y, groups=subjects))

X_train, X_val = X[train_idx], X[val_idx]
y_train, y_val = y[train_idx], y[val_idx]

train_ds = EEGTorchDataset(X_train, y_train)
val_ds   = EEGTorchDataset(X_val,   y_val)

pin     = torch.cuda.is_available()
sampler = make_weighted_sampler(y_train)

train_loader = DataLoader(
    train_ds,
    batch_size=32,
    shuffle=True,
    num_workers=2,
    pin_memory=pin
)
val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                          num_workers=2, pin_memory=pin)
# Out:
# Total files: 1526  |  After run filter: 654
# Total files: 1526  |  After run filter: 654
# /tmp/ipykernel_116/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_116/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_116/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_116/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_116/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# /tmp/ipykernel_116/2119066075.py:91: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(file, preload=True, verbose=False)
# Skipped: 0 / 654
# X shape  : (9795, 44, 641)  dtype: float32
# y shape  : (9795,)  classes: [0 1 2 3]
# Per class: [2452 2445 2470 2428]
# Classes: [0 1 2 3]  →  [0 1 2 3]
# Electrode positions: 44 / 44 matched
#
# Final X : (9795, 44, 641)
# Classes : 4  per class: [2452 2445 2470 2428]
# Class counts: [1956 1957 1973 1940]

# %%
model = ATCNet_LSTM(n_channels=44, n_times=641, num_classes=4)

device       = get_device()
class_counts = np.bincount(y_train)

print(f"\nDevice : {device}")
print(f"Input shape : {train_ds[0][0].shape}")  # (44, 641)
# Out:
# Device : cuda
# Input shape : torch.Size([44, 641])

# %%
train(model, train_loader, val_loader, device, epochs=200, class_counts=class_counts,
      patience=90, save_path='/kaggle/working/eeg_model_best.pth')

save_model(model, num_classes, label_encoder, ch_names, matched_ch)
# Out:
# Using weighted loss: [0.25005502 0.24992724 0.24790047 0.25211734]
# Epoch 01/200  train_loss=337.95  val_loss=84.93  train_acc=27.2%  val_acc=30.6%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 02/200  train_loss=334.85  val_loss=85.12  train_acc=29.3%  val_acc=30.8%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 03/200  train_loss=332.62  val_loss=84.34  train_acc=32.3%  val_acc=33.3%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 04/200  train_loss=327.05  val_loss=82.77  train_acc=34.9%  val_acc=36.2%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 05/200  train_loss=321.07  val_loss=84.45  train_acc=36.9%  val_acc=33.2%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 06/200  train_loss=316.85  val_loss=83.01  train_acc=38.8%  val_acc=35.4%  lr=1.00e-04
#   no improvement (2/90)
# Epoch 07/200  train_loss=312.36  val_loss=79.93  train_acc=40.1%  val_acc=39.3%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 08/200  train_loss=308.82  val_loss=83.35  train_acc=40.4%  val_acc=36.0%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 09/200  train_loss=306.47  val_loss=79.90  train_acc=42.2%  val_acc=40.4%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 10/200  train_loss=302.13  val_loss=78.90  train_acc=42.6%  val_acc=39.8%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 11/200  train_loss=298.59  val_loss=77.62  train_acc=44.1%  val_acc=39.8%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 12/200  train_loss=296.10  val_loss=80.69  train_acc=44.2%  val_acc=39.1%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 13/200  train_loss=295.04  val_loss=82.00  train_acc=44.3%  val_acc=38.2%  lr=1.00e-04
#   no improvement (2/90)
# Epoch 14/200  train_loss=292.45  val_loss=79.00  train_acc=45.2%  val_acc=40.3%  lr=1.00e-04
#   no improvement (3/90)
# Epoch 15/200  train_loss=288.51  val_loss=80.29  train_acc=45.7%  val_acc=41.9%  lr=1.00e-04
#   no improvement (4/90)
# Epoch 16/200  train_loss=286.82  val_loss=78.53  train_acc=46.6%  val_acc=43.3%  lr=1.00e-04
#   no improvement (5/90)
# Epoch 17/200  train_loss=284.31  val_loss=78.29  train_acc=47.3%  val_acc=43.7%  lr=1.00e-04
#   no improvement (6/90)
# Epoch 18/200  train_loss=284.14  val_loss=77.35  train_acc=47.2%  val_acc=43.0%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 19/200  train_loss=280.11  val_loss=75.85  train_acc=48.0%  val_acc=44.7%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 20/200  train_loss=279.07  val_loss=77.56  train_acc=48.2%  val_acc=43.4%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 21/200  train_loss=276.26  val_loss=74.27  train_acc=48.9%  val_acc=46.3%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 22/200  train_loss=271.79  val_loss=75.70  train_acc=49.5%  val_acc=45.9%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 23/200  train_loss=271.80  val_loss=73.41  train_acc=49.8%  val_acc=48.1%  lr=1.00e-04
#   val_loss improved → best model saved
# Epoch 24/200  train_loss=267.71  val_loss=74.70  train_acc=49.8%  val_acc=46.8%  lr=1.00e-04
#   no improvement (1/90)
# Epoch 25/200  train_loss=266.09  val_loss=73.64  train_acc=50.2%  val_acc=48.0%  lr=7.00e-05
#   no improvement (2/90)
# Epoch 26/200  train_loss=262.19  val_loss=72.84  train_acc=52.0%  val_acc=48.3%  lr=7.00e-05
#   val_loss improved → best model saved
# Epoch 27/200  train_loss=260.90  val_loss=73.39  train_acc=52.4%  val_acc=48.6%  lr=7.00e-05
#   no improvement (1/90)
# Epoch 28/200  train_loss=256.89  val_loss=73.27  train_acc=52.4%  val_acc=47.7%  lr=7.00e-05
#   no improvement (2/90)
# Epoch 29/200  train_loss=256.90  val_loss=76.18  train_acc=52.3%  val_acc=47.0%  lr=7.00e-05
#   no improvement (3/90)
# Epoch 30/200  train_loss=252.33  val_loss=71.14  train_acc=52.9%  val_acc=49.8%  lr=7.00e-05
#   val_loss improved → best model saved
# Epoch 31/200  train_loss=253.97  val_loss=75.11  train_acc=53.6%  val_acc=48.4%  lr=7.00e-05
#   no improvement (1/90)
# Epoch 32/200  train_loss=254.19  val_loss=73.52  train_acc=53.0%  val_acc=48.3%  lr=7.00e-05
#   no improvement (2/90)
# Epoch 33/200  train_loss=249.61  val_loss=71.73  train_acc=53.9%  val_acc=48.6%  lr=7.00e-05
#   no improvement (3/90)
# Epoch 34/200  train_loss=250.40  val_loss=72.37  train_acc=53.8%  val_acc=50.0%  lr=7.00e-05
#   no improvement (4/90)
# Epoch 35/200  train_loss=249.65  val_loss=73.87  train_acc=54.0%  val_acc=47.6%  lr=7.00e-05
#   no improvement (5/90)
# Epoch 36/200  train_loss=246.97  val_loss=73.04  train_acc=55.1%  val_acc=50.1%  lr=7.00e-05
#   no improvement (6/90)
# Epoch 37/200  train_loss=246.40  val_loss=72.11  train_acc=54.4%  val_acc=50.4%  lr=7.00e-05
#   no improvement (7/90)
# Epoch 38/200  train_loss=243.95  val_loss=73.72  train_acc=55.2%  val_acc=50.6%  lr=7.00e-05
#   no improvement (8/90)
# Epoch 39/200  train_loss=243.08  val_loss=74.61  train_acc=55.9%  val_acc=49.3%  lr=7.00e-05
#   no improvement (9/90)
# Epoch 40/200  train_loss=240.18  val_loss=71.97  train_acc=56.5%  val_acc=49.5%  lr=7.00e-05
#   no improvement (10/90)
# Epoch 41/200  train_loss=241.41  val_loss=71.63  train_acc=55.7%  val_acc=50.1%  lr=7.00e-05
#   no improvement (11/90)
# Epoch 42/200  train_loss=241.34  val_loss=72.34  train_acc=55.6%  val_acc=50.0%  lr=7.00e-05
#   no improvement (12/90)
# Epoch 43/200  train_loss=236.58  val_loss=72.63  train_acc=56.5%  val_acc=49.9%  lr=7.00e-05
#   no improvement (13/90)
# Epoch 44/200  train_loss=237.20  val_loss=74.78  train_acc=56.4%  val_acc=48.2%  lr=7.00e-05
#   no improvement (14/90)
# Epoch 45/200  train_loss=240.88  val_loss=73.75  train_acc=55.6%  val_acc=49.6%  lr=7.00e-05
#   no improvement (15/90)
# Epoch 46/200  train_loss=236.83  val_loss=73.30  train_acc=56.2%  val_acc=50.6%  lr=7.00e-05
#   no improvement (16/90)
# Epoch 47/200  train_loss=233.28  val_loss=73.46  train_acc=56.9%  val_acc=50.3%  lr=7.00e-05
#   no improvement (17/90)
# Epoch 48/200  train_loss=234.53  val_loss=73.27  train_acc=57.6%  val_acc=50.1%  lr=7.00e-05
#   no improvement (18/90)
# Epoch 49/200  train_loss=234.20  val_loss=72.31  train_acc=57.4%  val_acc=51.1%  lr=7.00e-05
#   no improvement (19/90)
# Epoch 50/200  train_loss=231.10  val_loss=76.06  train_acc=58.2%  val_acc=50.5%  lr=4.90e-05
#   no improvement (20/90)
# Epoch 51/200  train_loss=228.85  val_loss=73.76  train_acc=58.4%  val_acc=51.0%  lr=4.90e-05
#   no improvement (21/90)
# Epoch 52/200  train_loss=225.90  val_loss=72.15  train_acc=58.9%  val_acc=50.6%  lr=4.90e-05
#   no improvement (22/90)
# Epoch 53/200  train_loss=228.52  val_loss=75.00  train_acc=58.7%  val_acc=50.9%  lr=4.90e-05
#   no improvement (23/90)
# Epoch 54/200  train_loss=225.84  val_loss=72.26  train_acc=59.1%  val_acc=52.5%  lr=4.90e-05
#   no improvement (24/90)
# Epoch 55/200  train_loss=224.49  val_loss=74.99  train_acc=58.5%  val_acc=51.7%  lr=4.90e-05
#   no improvement (25/90)
# Epoch 56/200  train_loss=224.41  val_loss=71.73  train_acc=59.3%  val_acc=52.0%  lr=4.90e-05
#   no improvement (26/90)
# Epoch 57/200  train_loss=223.66  val_loss=73.59  train_acc=59.5%  val_acc=51.4%  lr=4.90e-05
#   no improvement (27/90)
# Epoch 58/200  train_loss=224.02  val_loss=71.83  train_acc=59.9%  val_acc=51.7%  lr=4.90e-05
#   no improvement (28/90)
# Epoch 59/200  train_loss=224.55  val_loss=73.58  train_acc=59.9%  val_acc=51.6%  lr=4.90e-05
#   no improvement (29/90)
# Epoch 60/200  train_loss=220.10  val_loss=74.11  train_acc=60.4%  val_acc=51.2%  lr=4.90e-05
#   no improvement (30/90)
# Epoch 61/200  train_loss=222.98  val_loss=73.08  train_acc=59.5%  val_acc=51.9%  lr=4.90e-05
#   no improvement (31/90)
# Epoch 62/200  train_loss=219.89  val_loss=71.96  train_acc=60.5%  val_acc=52.4%  lr=4.90e-05
#   no improvement (32/90)
# Epoch 63/200  train_loss=217.63  val_loss=71.42  train_acc=60.2%  val_acc=52.9%  lr=4.90e-05
#   no improvement (33/90)
# Epoch 64/200  train_loss=219.30  val_loss=74.15  train_acc=60.1%  val_acc=50.4%  lr=4.90e-05
#   no improvement (34/90)
# Epoch 65/200  train_loss=219.49  val_loss=75.33  train_acc=60.5%  val_acc=52.0%  lr=4.90e-05
#   no improvement (35/90)
# Epoch 66/200  train_loss=215.76  val_loss=74.55  train_acc=60.7%  val_acc=51.1%  lr=4.90e-05
#   no improvement (36/90)
# Epoch 67/200  train_loss=215.55  val_loss=76.37  train_acc=61.3%  val_acc=51.4%  lr=4.90e-05
#   no improvement (37/90)
# Epoch 68/200  train_loss=216.51  val_loss=79.31  train_acc=61.3%  val_acc=50.4%  lr=4.90e-05
#   no improvement (38/90)
# Epoch 69/200  train_loss=213.95  val_loss=78.25  train_acc=61.7%  val_acc=50.5%  lr=4.90e-05
#   no improvement (39/90)
# Epoch 70/200  train_loss=212.23  val_loss=75.55  train_acc=62.7%  val_acc=51.5%  lr=4.90e-05
#   no improvement (40/90)
# Epoch 71/200  train_loss=211.71  val_loss=76.75  train_acc=62.9%  val_acc=51.5%  lr=4.90e-05
#   no improvement (41/90)
# Epoch 72/200  train_loss=215.43  val_loss=75.31  train_acc=60.7%  val_acc=51.6%  lr=4.90e-05
#   no improvement (42/90)
# Epoch 73/200  train_loss=214.23  val_loss=74.15  train_acc=61.1%  val_acc=51.4%  lr=4.90e-05
#   no improvement (43/90)
# Epoch 74/200  train_loss=212.33  val_loss=76.48  train_acc=62.0%  val_acc=51.3%  lr=4.90e-05
#   no improvement (44/90)
# Epoch 75/200  train_loss=210.25  val_loss=77.11  train_acc=62.3%  val_acc=51.9%  lr=3.43e-05
#   no improvement (45/90)
# Epoch 76/200  train_loss=209.25  val_loss=74.86  train_acc=62.4%  val_acc=51.1%  lr=3.43e-05
#   no improvement (46/90)
# Epoch 77/200  train_loss=205.62  val_loss=74.26  train_acc=63.5%  val_acc=50.6%  lr=3.43e-05
#   no improvement (47/90)
# Epoch 78/200  train_loss=205.28  val_loss=75.19  train_acc=63.3%  val_acc=51.4%  lr=3.43e-05
#   no improvement (48/90)
# Epoch 79/200  train_loss=206.65  val_loss=76.95  train_acc=63.5%  val_acc=51.3%  lr=3.43e-05
#   no improvement (49/90)
# Epoch 80/200  train_loss=204.25  val_loss=76.08  train_acc=63.6%  val_acc=52.0%  lr=3.43e-05
#   no improvement (50/90)
# Epoch 81/200  train_loss=206.36  val_loss=75.27  train_acc=63.3%  val_acc=51.2%  lr=3.43e-05
#   no improvement (51/90)
# Epoch 82/200  train_loss=206.30  val_loss=75.85  train_acc=63.1%  val_acc=51.0%  lr=3.43e-05
#   no improvement (52/90)
# Epoch 83/200  train_loss=207.98  val_loss=76.35  train_acc=62.5%  val_acc=51.2%  lr=3.43e-05
#   no improvement (53/90)
# Epoch 84/200  train_loss=205.64  val_loss=77.69  train_acc=63.7%  val_acc=52.1%  lr=3.43e-05
#   no improvement (54/90)
# Epoch 85/200  train_loss=204.98  val_loss=75.22  train_acc=64.1%  val_acc=51.5%  lr=3.43e-05
#   no improvement (55/90)
# Epoch 86/200  train_loss=203.93  val_loss=77.22  train_acc=64.8%  val_acc=50.8%  lr=3.43e-05
#   no improvement (56/90)
# Epoch 87/200  train_loss=203.12  val_loss=74.79  train_acc=64.0%  val_acc=51.8%  lr=3.43e-05
#   no improvement (57/90)
# Epoch 88/200  train_loss=203.02  val_loss=77.06  train_acc=63.7%  val_acc=51.4%  lr=3.43e-05
#   no improvement (58/90)
# Epoch 89/200  train_loss=203.02  val_loss=77.49  train_acc=63.0%  val_acc=51.9%  lr=3.43e-05
#   no improvement (59/90)
# Epoch 90/200  train_loss=203.61  val_loss=74.85  train_acc=63.4%  val_acc=51.5%  lr=3.43e-05
#   no improvement (60/90)
# Epoch 91/200  train_loss=203.46  val_loss=75.83  train_acc=63.5%  val_acc=50.9%  lr=3.43e-05
#   no improvement (61/90)
# Epoch 92/200  train_loss=203.53  val_loss=78.40  train_acc=64.3%  val_acc=51.0%  lr=3.43e-05
#   no improvement (62/90)
# Epoch 93/200  train_loss=202.75  val_loss=75.06  train_acc=63.9%  val_acc=52.3%  lr=3.43e-05
#   no improvement (63/90)
# Epoch 94/200  train_loss=202.78  val_loss=75.47  train_acc=63.7%  val_acc=52.1%  lr=3.43e-05
#   no improvement (64/90)
# Epoch 95/200  train_loss=200.46  val_loss=76.16  train_acc=64.5%  val_acc=51.1%  lr=3.43e-05
#   no improvement (65/90)
# Epoch 96/200  train_loss=198.72  val_loss=78.45  train_acc=65.1%  val_acc=51.1%  lr=3.43e-05
#   no improvement (66/90)
# Epoch 97/200  train_loss=197.08  val_loss=76.61  train_acc=65.0%  val_acc=51.1%  lr=3.43e-05
#   no improvement (67/90)
# Epoch 98/200  train_loss=200.00  val_loss=74.62  train_acc=64.6%  val_acc=51.5%  lr=3.43e-05
#   no improvement (68/90)
# Epoch 99/200  train_loss=200.72  val_loss=77.19  train_acc=65.3%  val_acc=52.4%  lr=3.43e-05
#   no improvement (69/90)
# Epoch 100/200  train_loss=197.16  val_loss=79.05  train_acc=64.7%  val_acc=52.2%  lr=2.40e-05
#   no improvement (70/90)
# Epoch 101/200  train_loss=194.92  val_loss=80.49  train_acc=65.4%  val_acc=52.6%  lr=2.40e-05
#   no improvement (71/90)
# Epoch 102/200  train_loss=195.14  val_loss=80.09  train_acc=65.7%  val_acc=51.8%  lr=2.40e-05
#   no improvement (72/90)
# Epoch 103/200  train_loss=197.54  val_loss=79.49  train_acc=64.9%  val_acc=52.0%  lr=2.40e-05
#   no improvement (73/90)
# Epoch 104/200  train_loss=196.06  val_loss=81.00  train_acc=65.3%  val_acc=51.3%  lr=2.40e-05
#   no improvement (74/90)
# Epoch 105/200  train_loss=194.49  val_loss=77.54  train_acc=65.6%  val_acc=52.1%  lr=2.40e-05
#   no improvement (75/90)
# Epoch 106/200  train_loss=195.04  val_loss=76.81  train_acc=66.0%  val_acc=52.3%  lr=2.40e-05
#   no improvement (76/90)
# Epoch 107/200  train_loss=192.88  val_loss=78.53  train_acc=66.7%  val_acc=52.0%  lr=2.40e-05
#   no improvement (77/90)
# Epoch 108/200  train_loss=194.02  val_loss=79.09  train_acc=65.8%  val_acc=51.8%  lr=2.40e-05
#   no improvement (78/90)
# Epoch 109/200  train_loss=194.66  val_loss=80.05  train_acc=66.3%  val_acc=51.3%  lr=2.40e-05
#   no improvement (79/90)
# Epoch 110/200  train_loss=193.03  val_loss=78.51  train_acc=65.9%  val_acc=51.8%  lr=2.40e-05
#   no improvement (80/90)
# Epoch 111/200  train_loss=192.47  val_loss=77.96  train_acc=65.7%  val_acc=51.0%  lr=2.40e-05
#   no improvement (81/90)
# Epoch 112/200  train_loss=192.08  val_loss=81.24  train_acc=66.4%  val_acc=51.1%  lr=2.40e-05
#   no improvement (82/90)
# Epoch 113/200  train_loss=193.60  val_loss=78.96  train_acc=65.9%  val_acc=51.1%  lr=2.40e-05
#   no improvement (83/90)
# Epoch 114/200  train_loss=191.64  val_loss=79.16  train_acc=65.4%  val_acc=50.8%  lr=2.40e-05
#   no improvement (84/90)
# Epoch 115/200  train_loss=191.67  val_loss=80.16  train_acc=66.3%  val_acc=51.2%  lr=2.40e-05
#   no improvement (85/90)
# Epoch 116/200  train_loss=189.97  val_loss=80.82  train_acc=66.3%  val_acc=51.4%  lr=2.40e-05
#   no improvement (86/90)
# Epoch 117/200  train_loss=192.36  val_loss=78.07  train_acc=66.2%  val_acc=51.3%  lr=2.40e-05
#   no improvement (87/90)
# Epoch 118/200  train_loss=194.10  val_loss=78.37  train_acc=66.2%  val_acc=51.4%  lr=2.40e-05
#   no improvement (88/90)
# Epoch 119/200  train_loss=189.25  val_loss=76.87  train_acc=66.7%  val_acc=51.5%  lr=2.40e-05
#   no improvement (89/90)
# Epoch 120/200  train_loss=192.50  val_loss=80.01  train_acc=66.6%  val_acc=51.5%  lr=2.40e-05
#   no improvement (90/90)
#
#  Early stopping at epoch 120 — best val_loss=71.1352
#
#  Best model restored from /kaggle/working/eeg_model_best.pth
# Model saved → /kaggle/working/eeg_model.pth

# %%
label_names = ["Left fist", "Right fist", "Both fists", "Both feet"]
evaluate(model, val_loader, device, label_names=label_names)

plot_confusion_matrix(model, val_loader, device, label_names)
plt.savefig('/kaggle/working/confusion_matrix.png')
# Out:
# Val Accuracy: 49.82%
#
#               precision    recall  f1-score   support
#
#    Left fist       0.45      0.52      0.49       496
#   Right fist       0.47      0.52      0.50       488
#   Both fists       0.54      0.48      0.51       497
#    Both feet       0.55      0.47      0.51       488
#
#     accuracy                           0.50      1969
#    macro avg       0.50      0.50      0.50      1969
# weighted avg       0.50      0.50      0.50      1969

# %%
def get_device():
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")

DEVICE = get_device()

# %%
def model_tuning(model, num_classes: int = 4, device: torch.device = None) -> tuple:
    device = device or DEVICE

    for p in model.parameters():
        p.requires_grad = False

    for p in model.classifier.parameters():
        p.requires_grad = True

    
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=5e-3,
        weight_decay=1e-4
    )
    for param_group in optimizer.param_groups:
        param_group['lr'] = 3e-3
    scheduler = torch.optim.lr_scheduler.StepLR(
            optimizer, step_size=20, gamma=0.7  
        )

    total     = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n  Params: {total:,} total  |  {trainable:,} trainable "
          f"({100 * trainable / total:.1f}%)")

    return model.to(device), optimizer, scheduler

# %%
tuned_model = ATCNet_LSTM(n_channels=44, num_classes=4)
tuned_model.load_state_dict(
    torch.load('/kaggle/working/eeg_model_best.pth', weights_only=False),
    strict=False
)

tuned_model, optimizer_ft, scheduler_ft = model_tuning(tuned_model)
# Out:
#   Params: 2,463,507 total  |  164,740 trainable (6.7%)

# %%
def augment_eeg(X, noise_std=0.05, shift_max=20):
    X_aug = X.copy()
    N, C, T = X_aug.shape

    X_aug += np.random.randn(*X_aug.shape).astype(np.float32) * noise_std

    shifts = np.random.randint(-shift_max, shift_max, size=N)
    for i, s in enumerate(shifts):
        X_aug[i] = np.roll(X_aug[i], s, axis=-1)

    return X_aug

# %%
for f in ["/kaggle/working/cache_train.npy", "/kaggle/working/cache_val.npy"]:
    if os.path.exists(f):
        os.remove(f)
        print(f"Deleted old cache: {f}")

builder_tune = EEGDatasetBuilder(DATA_PATH)
X, y_raw, ch_names, subjects = builder_tune.build(tune=1)
 
y, label_encoder = encode_labels(y_raw)
num_classes      = len(label_encoder.classes_)
class_counts = np.bincount(y)
 
# Data augmentation 
X_aug = augment_eeg(X, noise_std=0.03, shift_max=15)
X_all = np.concatenate([X, X_aug], axis=0)
y_all = np.concatenate([y, y], axis=0)
 
print(f"After augmentation: X={X_all.shape}, y={y_all.shape}")
 
train_idx, val_idx = train_test_split(
    np.arange(len(X_all)),
    test_size=0.3,    
    random_state=42,
    stratify=y_all
)
 
X_train_tuning, X_val_tuning = X_all[train_idx], X_all[val_idx]
y_train_tuning, y_val_tuning = y_all[train_idx], y_all[val_idx]
 
train_ds_tuning = EEGTorchDataset(X_train_tuning, y_train_tuning)
val_ds_tuning   = EEGTorchDataset(X_val_tuning,   y_val_tuning) 
 
pin     = torch.cuda.is_available()
sampler = make_weighted_sampler(y_train_tuning)
 
train_loader_tuning = DataLoader(train_ds_tuning, batch_size=32, sampler=sampler,
                                  num_workers=2, pin_memory=pin)
val_loader_tuning   = DataLoader(val_ds_tuning,   batch_size=32, shuffle=False,
                                  num_workers=2, pin_memory=pin)
# Out:
# Total files: 1526  |  After run filter: 654
# Total files: 1526  |  After run filter: 654
# Skipped: 0 / 6
# X shape  : (90, 44, 641)  dtype: float32
# y shape  : (90,)  classes: [0 1 2 3]
# Per class: [23 22 23 22]
# Classes: [0 1 2 3]  →  [0 1 2 3]
# After augmentation: X=(180, 44, 641), y=(180,)
# Class counts: [46 44 46 44]

# %%
train(tuned_model, train_loader_tuning, val_loader_tuning, device, optimizer_ft, scheduler_ft, epochs=70, class_counts=class_counts, patience=50, save_path='/kaggle/working/best_tuned_model.pth')

label_names = ["Left fist", "Right fist", "Both fists", "Both feet"]
evaluate(tuned_model, val_loader_tuning, device, label_names=label_names)

save_model(tuned_model, num_classes, label_encoder, ch_names, matched_ch)
# Out:
# Using weighted loss: [0.24444443 0.25555554 0.24444443 0.25555554]
# Epoch 01/70  train_loss=7.17  val_loss=3.64  train_acc=45.0%  val_acc=36.7%  lr=7.20e-04
#   val_loss improved → best model saved
# Epoch 02/70  train_loss=7.02  val_loss=3.64  train_acc=48.9%  val_acc=38.9%  lr=7.20e-04
#   val_loss improved → best model saved
# Epoch 03/70  train_loss=7.37  val_loss=3.59  train_acc=41.7%  val_acc=38.9%  lr=7.20e-04
#   val_loss improved → best model saved
# Epoch 04/70  train_loss=7.64  val_loss=3.47  train_acc=38.9%  val_acc=46.7%  lr=7.20e-04
#   val_loss improved → best model saved
# Epoch 05/70  train_loss=7.30  val_loss=3.46  train_acc=42.2%  val_acc=48.9%  lr=5.04e-04
#   val_loss improved → best model saved
# Epoch 06/70  train_loss=7.18  val_loss=3.50  train_acc=47.2%  val_acc=47.8%  lr=5.04e-04
#   no improvement (1/50)
# Epoch 07/70  train_loss=7.32  val_loss=3.54  train_acc=40.6%  val_acc=45.6%  lr=5.04e-04
#   no improvement (2/50)
# Epoch 08/70  train_loss=7.56  val_loss=3.55  train_acc=41.1%  val_acc=44.4%  lr=5.04e-04
#   no improvement (3/50)
# Epoch 09/70  train_loss=7.77  val_loss=3.55  train_acc=33.3%  val_acc=42.2%  lr=5.04e-04
#   no improvement (4/50)
# Epoch 10/70  train_loss=7.47  val_loss=3.52  train_acc=40.6%  val_acc=44.4%  lr=5.04e-04
#   no improvement (5/50)
# Epoch 11/70  train_loss=7.49  val_loss=3.51  train_acc=38.9%  val_acc=47.8%  lr=5.04e-04
#   no improvement (6/50)
# Epoch 12/70  train_loss=7.22  val_loss=3.51  train_acc=43.9%  val_acc=47.8%  lr=5.04e-04
#   no improvement (7/50)
# Epoch 13/70  train_loss=7.29  val_loss=3.48  train_acc=50.0%  val_acc=46.7%  lr=5.04e-04
#   no improvement (8/50)
# Epoch 14/70  train_loss=7.40  val_loss=3.51  train_acc=40.6%  val_acc=45.6%  lr=5.04e-04
#   no improvement (9/50)
# Epoch 15/70  train_loss=7.06  val_loss=3.49  train_acc=41.1%  val_acc=46.7%  lr=5.04e-04
#   no improvement (10/50)
# Epoch 16/70  train_loss=7.22  val_loss=3.44  train_acc=42.8%  val_acc=46.7%  lr=5.04e-04
#   val_loss improved → best model saved
# Epoch 17/70  train_loss=7.19  val_loss=3.40  train_acc=45.0%  val_acc=50.0%  lr=5.04e-04
#   val_loss improved → best model saved
# Epoch 18/70  train_loss=7.27  val_loss=3.38  train_acc=37.8%  val_acc=52.2%  lr=5.04e-04
#   val_loss improved → best model saved
# Epoch 19/70  train_loss=7.60  val_loss=3.38  train_acc=40.6%  val_acc=56.7%  lr=5.04e-04
#   val_loss improved → best model saved
# Epoch 20/70  train_loss=7.09  val_loss=3.42  train_acc=40.0%  val_acc=50.0%  lr=5.04e-04
#   no improvement (1/50)
# Epoch 21/70  train_loss=7.34  val_loss=3.46  train_acc=37.2%  val_acc=47.8%  lr=5.04e-04
#   no improvement (2/50)
# Epoch 22/70  train_loss=7.09  val_loss=3.48  train_acc=50.0%  val_acc=45.6%  lr=5.04e-04
#   no improvement (3/50)
# Epoch 23/70  train_loss=7.52  val_loss=3.44  train_acc=40.6%  val_acc=46.7%  lr=5.04e-04
#   no improvement (4/50)
# Epoch 24/70  train_loss=7.30  val_loss=3.41  train_acc=42.8%  val_acc=53.3%  lr=5.04e-04
#   no improvement (5/50)
# Epoch 25/70  train_loss=7.14  val_loss=3.41  train_acc=44.4%  val_acc=54.4%  lr=3.53e-04
#   no improvement (6/50)
# Epoch 26/70  train_loss=7.92  val_loss=3.39  train_acc=36.1%  val_acc=53.3%  lr=3.53e-04
#   no improvement (7/50)
# Epoch 27/70  train_loss=7.62  val_loss=3.39  train_acc=36.7%  val_acc=53.3%  lr=3.53e-04
#   no improvement (8/50)
# Epoch 28/70  train_loss=7.51  val_loss=3.39  train_acc=40.6%  val_acc=55.6%  lr=3.53e-04
#   no improvement (9/50)
# Epoch 29/70  train_loss=7.25  val_loss=3.41  train_acc=43.3%  val_acc=53.3%  lr=3.53e-04
#   no improvement (10/50)
# Epoch 30/70  train_loss=7.48  val_loss=3.44  train_acc=38.3%  val_acc=52.2%  lr=3.53e-04
#   no improvement (11/50)
# Epoch 31/70  train_loss=7.36  val_loss=3.46  train_acc=43.3%  val_acc=50.0%  lr=3.53e-04
#   no improvement (12/50)
# Epoch 32/70  train_loss=7.45  val_loss=3.44  train_acc=42.8%  val_acc=48.9%  lr=3.53e-04
#   no improvement (13/50)
# Epoch 33/70  train_loss=7.53  val_loss=3.44  train_acc=40.6%  val_acc=48.9%  lr=3.53e-04
#   no improvement (14/50)
# Epoch 34/70  train_loss=7.52  val_loss=3.43  train_acc=36.1%  val_acc=47.8%  lr=3.53e-04
#   no improvement (15/50)
# Epoch 35/70  train_loss=7.48  val_loss=3.42  train_acc=40.0%  val_acc=47.8%  lr=3.53e-04
#   no improvement (16/50)
# Epoch 36/70  train_loss=7.69  val_loss=3.41  train_acc=43.9%  val_acc=46.7%  lr=3.53e-04
#   no improvement (17/50)
# Epoch 37/70  train_loss=7.16  val_loss=3.39  train_acc=42.8%  val_acc=45.6%  lr=3.53e-04
#   no improvement (18/50)
# Epoch 38/70  train_loss=7.30  val_loss=3.42  train_acc=38.9%  val_acc=44.4%  lr=3.53e-04
#   no improvement (19/50)
# Epoch 39/70  train_loss=7.56  val_loss=3.46  train_acc=37.8%  val_acc=42.2%  lr=3.53e-04
#   no improvement (20/50)
# Epoch 40/70  train_loss=7.50  val_loss=3.50  train_acc=38.9%  val_acc=42.2%  lr=3.53e-04
#   no improvement (21/50)
# Epoch 41/70  train_loss=7.25  val_loss=3.45  train_acc=42.2%  val_acc=44.4%  lr=3.53e-04
#   no improvement (22/50)
# Epoch 42/70  train_loss=7.83  val_loss=3.41  train_acc=34.4%  val_acc=47.8%  lr=3.53e-04
#   no improvement (23/50)
# Epoch 43/70  train_loss=7.69  val_loss=3.39  train_acc=40.6%  val_acc=48.9%  lr=3.53e-04
#   no improvement (24/50)
# Epoch 44/70  train_loss=7.31  val_loss=3.36  train_acc=44.4%  val_acc=53.3%  lr=3.53e-04
#   val_loss improved → best model saved
# Epoch 45/70  train_loss=7.49  val_loss=3.35  train_acc=38.3%  val_acc=52.2%  lr=2.47e-04
#   val_loss improved → best model saved
# Epoch 46/70  train_loss=7.45  val_loss=3.35  train_acc=41.1%  val_acc=52.2%  lr=2.47e-04
#   no improvement (1/50)
# Epoch 47/70  train_loss=7.47  val_loss=3.36  train_acc=40.0%  val_acc=53.3%  lr=2.47e-04
#   no improvement (2/50)
# Epoch 48/70  train_loss=7.45  val_loss=3.37  train_acc=43.3%  val_acc=53.3%  lr=2.47e-04
#   no improvement (3/50)
# Epoch 49/70  train_loss=7.28  val_loss=3.37  train_acc=36.1%  val_acc=51.1%  lr=2.47e-04
#   no improvement (4/50)
# Epoch 50/70  train_loss=7.34  val_loss=3.37  train_acc=43.9%  val_acc=54.4%  lr=2.47e-04
#   no improvement (5/50)
# Epoch 51/70  train_loss=7.27  val_loss=3.37  train_acc=46.1%  val_acc=54.4%  lr=2.47e-04
#   no improvement (6/50)
# Epoch 52/70  train_loss=7.31  val_loss=3.37  train_acc=41.7%  val_acc=55.6%  lr=2.47e-04
#   no improvement (7/50)
# Epoch 53/70  train_loss=7.66  val_loss=3.37  train_acc=36.7%  val_acc=56.7%  lr=2.47e-04
#   no improvement (8/50)
# Epoch 54/70  train_loss=7.84  val_loss=3.36  train_acc=38.9%  val_acc=54.4%  lr=2.47e-04
#   no improvement (9/50)
# Epoch 55/70  train_loss=7.33  val_loss=3.37  train_acc=41.1%  val_acc=52.2%  lr=2.47e-04
#   no improvement (10/50)
# Epoch 56/70  train_loss=7.43  val_loss=3.35  train_acc=42.2%  val_acc=52.2%  lr=2.47e-04
#   no improvement (11/50)
# Epoch 57/70  train_loss=7.61  val_loss=3.36  train_acc=43.3%  val_acc=52.2%  lr=2.47e-04
#   no improvement (12/50)
# Epoch 58/70  train_loss=7.25  val_loss=3.34  train_acc=41.7%  val_acc=56.7%  lr=2.47e-04
#   val_loss improved → best model saved
# Epoch 59/70  train_loss=7.47  val_loss=3.35  train_acc=39.4%  val_acc=56.7%  lr=2.47e-04
#   no improvement (1/50)
# Epoch 60/70  train_loss=7.34  val_loss=3.38  train_acc=41.7%  val_acc=51.1%  lr=2.47e-04
#   no improvement (2/50)
# Epoch 61/70  train_loss=7.19  val_loss=3.38  train_acc=35.6%  val_acc=48.9%  lr=2.47e-04
#   no improvement (3/50)
# Epoch 62/70  train_loss=7.03  val_loss=3.41  train_acc=44.4%  val_acc=43.3%  lr=2.47e-04
#   no improvement (4/50)
# Epoch 63/70  train_loss=7.21  val_loss=3.40  train_acc=41.7%  val_acc=46.7%  lr=2.47e-04
#   no improvement (5/50)
# Epoch 64/70  train_loss=7.43  val_loss=3.40  train_acc=39.4%  val_acc=51.1%  lr=2.47e-04
#   no improvement (6/50)
# Epoch 65/70  train_loss=7.64  val_loss=3.41  train_acc=36.7%  val_acc=50.0%  lr=1.73e-04
#   no improvement (7/50)
# Epoch 66/70  train_loss=7.31  val_loss=3.42  train_acc=43.3%  val_acc=53.3%  lr=1.73e-04
#   no improvement (8/50)
# Epoch 67/70  train_loss=7.35  val_loss=3.41  train_acc=38.9%  val_acc=53.3%  lr=1.73e-04
#   no improvement (9/50)
# Epoch 68/70  train_loss=6.89  val_loss=3.39  train_acc=47.2%  val_acc=53.3%  lr=1.73e-04
#   no improvement (10/50)
# Epoch 69/70  train_loss=7.52  val_loss=3.36  train_acc=37.8%  val_acc=54.4%  lr=1.73e-04
#   no improvement (11/50)
# Epoch 70/70  train_loss=7.70  val_loss=3.36  train_acc=37.2%  val_acc=53.3%  lr=1.73e-04
#   no improvement (12/50)
#
#  Best model restored from /kaggle/working/best_tuned_model.pth
#
# Val Accuracy: 56.67%
#
#               precision    recall  f1-score   support
#
#    Left fist       0.43      0.65      0.52        23
#   Right fist       0.72      0.59      0.65        22
#   Both fists       0.52      0.48      0.50        23
#    Both feet       0.75      0.55      0.63        22
#
#     accuracy                           0.57        90
#    macro avg       0.61      0.57      0.57        90
# weighted avg       0.60      0.57      0.57        90
#
# Model saved → /kaggle/working/eeg_model.pth

# %%
plot_confusion_matrix(tuned_model, val_loader_tuning, device, label_names)
plt.savefig('/kaggle/working/confusion_matrix_tuning.png')
